# %% [markdown]
# # Baseball Case Study - Evaluation Project 1

# %% [markdown]
# ![image_2022-11-26_193242313.png](attachment:image_2022-11-26_193242313.png)

# %% [markdown]
# # Importing the Dataset:

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("baseball.csv") #reading the data file
df #diplaying the dataset fully
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.shape #The Total number of data (same as df)
# Out:
# (30, 17)

# %%
df.columns #to see the columns names
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# -As mentioned in the problem statement the columns are Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, Complete Games and Errors
#
# - We see the size of datset is very lesser only 30 rows are given , so we cannot use this dataset for model building like this we need to do some Resampling
#
# -

# %%
df.head() #to see 5 first row of dataset
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# # Checking for NULL values if any in the data frame
#
# np.nan, None, NaN and others..

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# We see that this dataset has no null values so we wll go to the next step

# %%
#CAN ALSO USE

print (df.info()) #to check for null Values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB
# None

# %% [markdown]
# We have rechecked again and found no null values

# %% [markdown]
# # Check the datatypes of the columns

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# We can observe that there are in total 17 columns which are Object data i.e :-
#   - most of the scores are int data and one float data which is ERA , and most of the columns are continuos
#   - we see the W (Taret variable) is aso int and continuos so we have reconised this as a Regression Problem
# We can also observe that the Target variable (CGPA) is float data and Continuous in nature

# %% [markdown]
# ## Therefore , we can conclude from this part that this is a Regression Problem statement

# %%
df['W'].nunique() # we see there are some examples of unique data in the target variable
# Out:
# 24

# %%
#lets check for the categoriacal data as we will need to treat them 

df['R'].nunique()
# Out:
# 28

# %%
# Checking the unique values in each column

for col in df:
    print(df[col].nunique(),'\n')
# Out:
# 24
#
# 28
#
# 29
#
# 29
#
# 22
#
# 23
#
# 27
#
# 29
#
# 29
#
# 27
#
# 30
#
# 30
#
# 30
#
# 9
#
# 12
#
# 20
#
# 21

# %% [markdown]
# ## We see that most of the columns have continuos data and most are int as they contain match data and pertain to ne non decimal numbers except for ERA which is decimal as it is average of run

# %%
df['ERA'].nunique()
# Out:
# 30

# %%
df['E'].nunique()
# Out:
# 21

# %%
# Checking to see if any of the values in Charges is white spaces

df.loc[df['W'] == " "]
# Out:
# Empty DataFrame
# Columns: [W, R, AB, H, 2B, 3B, HR, BB, SO, SB, RA, ER, ERA, CG, SHO, SV, E]
# Index: []

# %% [markdown]
# We see no Whiteapaces too so lets move on to next step

# %% [markdown]
# # Visualization of the distribution of the continuous value of the float and int columns.

# %%
import seaborn as sns
import matplotlib.pyplot as plt


import warnings
warnings.filterwarnings('ignore')

# %%
#Lets see how the data is distributed for every column

plt.figure(figsize =(15,20), facecolor = 'white')
plotnumber = 1

for column in df:
    if plotnumber <=17:
        ax = plt.subplot(6,3,plotnumber)
        sns.histplot(df[column])
        plt.xlabel(column,fontsize = 12)
        
    plotnumber +=1
plt.tight_layout()

# %%
#Lets see how the data is distributed for every column

plt.figure(figsize =(15,20), facecolor = 'white')
plotnumber = 1

for column in df:
    if plotnumber <=17:
        ax = plt.subplot(6,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize = 12)
        
    plotnumber +=1
plt.tight_layout()

# %% [markdown]
# # Observations :-
#
#    - We see that the columns have relatively  normal data considering the size of dataset being too small
#
#    - We see that come columns have majority of data with in a specific range like R, 2R, H, SV, etc , most of them follow this
#
#    - which says that the teams are playing on level ground and there isnt much deviation in the stats of each match
#
#    -  We see 3R is having unifrm distribution wherein all the rows have same scores with number ,  Similar trensd is seen in FRA, and SV.
#
#    - the data is very less so we cannot assume that this is the overall range of that particular statistic, but for this dataset we can assume the following conditions

# %% [markdown]
# ## Lets graph the data for columns individually so we can make clear findings

# %%
sns.distplot(df['W'],kde=True,) #Target variable
# Out:
# <AxesSubplot:xlabel='W', ylabel='Density'>

# %% [markdown]
# We see that the max of the rows lie in range 80-85 and overall the data is very uniform , no outliers on either side , lets check with the histplot

# %%
sns.histplot(x=df.W, ec = "black", color='g', kde=True)
# Out:
# <AxesSubplot:xlabel='W', ylabel='Count'>

# %% [markdown]
# As we mentined before we see the same observations , where max of data is in 80-85 range

# %%
sns.distplot(df['R'],kde=True,)
# Out:
# <AxesSubplot:xlabel='R', ylabel='Density'>

# %%
sns.histplot(x=df.R, ec = "black", color='g', kde=True)
# Out:
# <AxesSubplot:xlabel='R', ylabel='Count'>

# %% [markdown]
# We see this column has relatively normally distributed data but we see some oulies in range 850-900 approx 1-2 count , which we need to treat
# Due t size of data set we can assume that the range in the columns is for this data set alone

# %%
sns.distplot(df['AB'],kde=True,)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='Density'>

# %%
sns.histplot(x=df.AB, ec = "black", color='g', kde=True)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='Count'>

# %% [markdown]
# The column has a really normally distributed data set and we see that it ranges from 5400 to 5650 , as the data shows thta the ranges is really high we will need to us us scale the data as the model does not become biased towards this column

# %%
sns.distplot(df['H'],kde=True,)
# Out:
# <AxesSubplot:xlabel='H', ylabel='Density'>

# %%
sns.histplot(x=df.H, ec = "black", color='g', kde=True)
# Out:
# <AxesSubplot:xlabel='H', ylabel='Count'>

# %% [markdown]
# The H column we see here is also having a relatively normally distributed data , the number of count at 1425 is very low but it is picking up as we move along the range towards 1450 +

# %%
sns.distplot(df['2B'],kde=True,)
# Out:
# <AxesSubplot:xlabel='2B', ylabel='Density'>

# %%
sns.histplot(x=df['2B'], ec = "black", color='g', kde=True)
# Out:
# <AxesSubplot:xlabel='2B', ylabel='Count'>

# %% [markdown]
# We see that the maximum frequency is between 270 and 285 and the lowest is 250 to 260 range.
# we see the data is normally distributed

# %%
sns.distplot(df['3B'],kde=True,)
# Out:
# <AxesSubplot:xlabel='3B', ylabel='Density'>

# %%
sns.histplot(x=df['3B'], ec = "black", color='g', kde=True)
# Out:
# <AxesSubplot:xlabel='3B', ylabel='Count'>

# %% [markdown]
# We see that there is uniform distribution in the range of this columns , we see that the max of the data is in range of 25 and 30

# %%
sns.distplot(df['HR'],kde=True,)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='Density'>

# %%
sns.histplot(x=df.HR, ec = "black", color='g', kde=True)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='Count'>

# %% [markdown]
# Here we see again some relatively normal distribution , just some columns have lower weightage , the highest here is 160 to 180 and lowest is 180 to 200

# %%
sns.distplot(df['BB'],kde=True,)
# Out:
# <AxesSubplot:xlabel='BB', ylabel='Density'>

# %%
sns.histplot(x=df.BB, ec = "black", color='g', kde=True)
# Out:
# <AxesSubplot:xlabel='BB', ylabel='Count'>

# %% [markdown]
# We see that there is uniform distribution of data and we see that the 500 and 525 is having the lowest , highest is 475 to 500

# %%
sns.distplot(df['SO'],kde=True,)
# Out:
# <AxesSubplot:xlabel='SO', ylabel='Density'>

# %%
sns.histplot(x=df.SO, ec = "black", color='g', kde=True)
# Out:
# <AxesSubplot:xlabel='SO', ylabel='Count'>

# %% [markdown]
# Here we see the majority of the data points are in range 1200 and 1300 and the data is normally distributes , the range is 1000 to 1500 so we need to standardize the data so the model is not biased

# %%
sns.distplot(df['SB'],kde=True,)
# Out:
# <AxesSubplot:xlabel='SB', ylabel='Density'>

# %%
sns.histplot(x=df.SB, ec = "black", color='g', kde=True)
# Out:
# <AxesSubplot:xlabel='SB', ylabel='Count'>

# %% [markdown]
# The data is normally distributed and we see range 60 to 90 is highest number of rowsand 100 to 110 is the lowest

# %%
sns.distplot(df['RA'],kde=True,)
# Out:
# <AxesSubplot:xlabel='RA', ylabel='Density'>

# %%
sns.histplot(x=df.RA, ec = "black", color='g', kde=True)
# Out:
# <AxesSubplot:xlabel='RA', ylabel='Count'>

# %% [markdown]
# Here is RA we see that the max is in range between 700 to 750 and we nave 1-2 count in 550 to 600 ,but data is normally distributed

# %%
sns.distplot(df['ER'],kde=True,)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='Density'>

# %%
sns.histplot(x=df.ER, ec = "black", color='g', kde=True)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='Count'>

# %% [markdown]
# In this columns the data is norally distributeda as well alomost , we see the max frequency is range 650 to 700 and lowest is 500 to 550

# %%
sns.distplot(df['ERA'],kde=True,)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='Density'>

# %%
sns.histplot(x=df.ERA, ec = "black", color='g', kde=True)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='Count'>

# %% [markdown]
# The data in ERA is very normally distributed and we see that the max range lies between 3.5 to 4.5

# %%
sns.distplot(df['CG'],kde=True,)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='Density'>

# %%
sns.histplot(x=df.CG, ec = "black", color='g', kde=True)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='Count'>

# %% [markdown]
# We see that the data is skewed towards the rught , we have some outliers in this columns from 9 to 10 whichis 1 count , but more or less the data is normally skewed

# %%
sns.distplot(df['SHO'],kde=True,)
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='Density'>

# %%
sns.histplot(x=df.SHO, ec = "black", color='g', kde=True)
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='Count'>

# %% [markdown]
# In the SHO columns as well we see that the data is normal relatively , the highest range is between 10.0 to 12.5 and the lowest is 15.0 to 17.5

# %%
sns.distplot(df['SV'],kde=True,)
# Out:
# <AxesSubplot:xlabel='SV', ylabel='Density'>

# %%
sns.histplot(x=df.SV, ec = "black", color='g', kde=True)
# Out:
# <AxesSubplot:xlabel='SV', ylabel='Count'>

# %% [markdown]
# IN the Sv columsn we alos see the same trend , ubut there is one count in 30 to 35 range and 50 to 60 have 4 counts but the highest of the column is in 35 to 40 range

# %%
sns.distplot(df['E'],kde=True,)
# Out:
# <AxesSubplot:xlabel='E', ylabel='Density'>

# %%
sns.histplot(x=df.E, ec = "black", color='g', kde=True)
# Out:
# <AxesSubplot:xlabel='E', ylabel='Count'>

# %% [markdown]
# The E columns which is also relatively normally distributed also has some ranges with too few values , we see that range 100 to 110 is having only 2 counts out of 30 . But we need to remeber that the dataset is very small so this may nit be true for the games statistic

# %%
sns.pairplot(df)

# %% [markdown]
# ## We see a number of observation in the pairplot , but the relatuionship is very hard to pinpoint so we will nedd to plot different relationship plots to find the actual reletionship between the columns

# %% [markdown]
# # Visualizing the relationship between the features and the target variable

# %%
#Divide data into features and label

x = df.drop(columns = ['W'])
y = df['W']

# %% [markdown]
# # Scatter plot

# %%
#Lets see how the data is distributed for every column as a whole

#Visualizing Relationship

plt.figure(figsize =(15,20), facecolor = 'yellow')
plotnumber = 1

for column in x:
    if plotnumber <=17:
        ax = plt.subplot(6,3,plotnumber)
        plt.scatter(x[column],y)
        plt.xlabel(column,fontsize = 20)
        plt.ylabel('W',fontsize = 10)
    plotnumber +=1
plt.tight_layout()

# %% [markdown]
# # Observations form the plots:-
#     - we see that the relationship of all thecolumns are not uniform , we also see that there are some columns which are
#        - not showing a trend or no relationship - i.e  AB , H , 3B, SB, CG, SHO, E
#        - showing postive relationship i.e R, 2B, HR, BB, SO, SV
#        -showing negative relationship i.e RA, ER, ERA,
#
#     - We need to remeber the size of the dataset to play a role in this formation of the pattern as well , as we have only 30 points in each plot

# %%
#Lets see how the data is distributed for every column as a whole

#Visualizing Relationship

plt.figure(figsize =(15,20), facecolor = 'white')
plotnumber = 1

for column in x:
    if plotnumber <=17:
        ax = plt.subplot(6,3,plotnumber)
        sns.lineplot(x[column],y)
        plt.xlabel(column,fontsize = 20)
        plt.ylabel('W',fontsize = 10)
    plotnumber +=1
plt.tight_layout()

# %% [markdown]
# Here in the line plot we also see the same kind of distribution as we see in the scatter plot which we used before and we see the same observations in this line plot as well

# %%
#Lets see how the data is distributed for every column as a whole

#Visualizing Relationship

plt.figure(figsize =(15,20), facecolor = 'white')
plotnumber = 1

for column in x:
    if plotnumber <=17:
        ax = plt.subplot(6,3,plotnumber)
        sns.boxplot(x[column],y)
        plt.xlabel(column,fontsize = 20)
        plt.ylabel('W',fontsize = 10)
    plotnumber +=1
plt.tight_layout()

# %% [markdown]
# Just showing the relationship in boxplot , but we are not able to see a definite relationship apart from the relation btw W and CG in this type of graph

# %%
#Lets see how the data is distributed for every column as a whole

#Visualizing Relationship

plt.figure(figsize =(15,20), facecolor = 'white')
plotnumber = 1

for column in x:
    if plotnumber <=17:
        ax = plt.subplot(6,3,plotnumber)
        sns.regplot(x[column],y)
        plt.xlabel(column,fontsize = 20)
        plt.ylabel('W',fontsize = 10)
    plotnumber +=1
plt.tight_layout()

# %% [markdown]
# # Finally we are using Reg plot to even more further prove that the observations made are showing the same relationship in thsi type of plot as well .
#
# # Observations form the plots:-
#     - we see that the relationship of all thecolumns are not uniform , we also see that there are some columns which are
#        - not showing a trend or no relationship - i.e  AB , H , 3B, SB, CG, SHO, E
#        - showing postive relationship i.e R, 2B, HR, BB, SO, SV
#        -showing negative relationship i.e RA, ER, ERA,
#
#     - We need to remeber the size of the dataset to play a role in this formation of the pattern as well , as we have only 30 points in each plot

# %% [markdown]
# # EDA

# %% [markdown]
# ### Describing the Dataset

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# # Observations:-
#
# - We see that the column CG has mean of 3.46 approx and Std of 2.776 and the min is 0 and max is 11 so there is some ouliers and we need to rtreat the skewness in the data
#
# - we see that the SHO columns has min of 4 and a max of 21 which shows some outliers are presendtin this columns as well
#
# - the rest of the columns do not show any signs of having extreme values or skewness as off now lets us plot it to study further
#
# - Lets us plot the data we have plotted now

# %% [markdown]
# # Visualization of the Data Properties

# %%
#Lets see how the data is distributed for every column

import matplotlib.pyplot as plt
plt.figure(figsize=(22,10))
sns.heatmap(df.describe(),annot=True,linewidths=0.1,linecolor="black",fmt='0.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## We see that the data is not scaled so we have some extreme values in AB column and H as well as SO column , there is some high values in BB, RA as well as ER so we need to treatthem by standardization

# %% [markdown]
# # Correlation of the columns with the target Columns

# %%
df.corr()['W'].sort_values()
# Out:
# ERA   -0.819600
# RA    -0.812952
# ER    -0.809435
# 3B    -0.251118
# SB    -0.157234
# E     -0.089485
# AB    -0.087947
# H      0.037612
# CG     0.080533
# SO     0.111850
# HR     0.307407
# 2B     0.427797
# R      0.430751
# SHO    0.471805
# BB     0.484342
# SV     0.666530
# W      1.000000
# Name: W, dtype: float64

# %% [markdown]
# ### We see that Sv has the highest correlation with the target variable having a score of 0.66 which is the highest and ERA, RA as well as ER have the lowest correlation with the target variable ,
#
# Overall the rest of the columns show very less correaltion or no correlation , but keeping in mind the size of the dataset we haveonly 30 vlaues , so we cannot assume that this statistic will not affect the target variable in a larger dataset

# %% [markdown]
# ## Heatmap of Correlation of the columns within the Columns or Features and Target

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#size of canvas
plt.figure(figsize=(35,20))
sns.heatmap(df.corr(),annot=True, linewidths=0.5,linecolor='black', fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Observations from the heatmap
#
# - we see that there is 100% multicollinearity as in relationshoip btw the columns :-
#   - ER and ERA
#   - RA and ERA
#   - RA and ER
# - This means it will lead to over fitting , so we must eliminate 2 of these columns and only keep one as it represents the rest of the 2, In this case we will keep ERA and eliminate ER and RA
#
# - We see that there is approx 74% correlation between H and AB whichis also pretty high so we will go ahead and remove on , In this case we will only keep AB as H has high correlation of 56% approx with 2B
#
# - We see correlation between R and HR but as we see that the relation is approx 67% and we have already removed the rest of the columns we will keep it till it does not drastically overfit or underfit the model
#
# - Therefore we will now move to remove thses columns after careful observations

# %%
# Plotting a barplot to see th relationship with label in a better way

df.drop('W', axis=1).corrwith(df.W).plot(kind='bar', grid=True,figsize=(32,15),
                                                  title='Correlation with target')

plt.show()

# %% [markdown]
# # Dropping the features which arehighly correlated to avoid Multicollinearity problem

# %%
df.drop(columns = ['ER','RA','H'], inplace=True)

# %% [markdown]
# # Dropping the duplicates

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (30, 14)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#size of canvas
plt.figure(figsize=(35,20))
sns.heatmap(df.corr(),annot=True, linewidths=0.5,linecolor='black', fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## We have removed the features overfitting the model and the heatmap looks a lot better now

# %%
# Plotting a barplot to see th relationship with label in a better way

df.drop('W', axis=1).corrwith(df.W).plot(kind='bar', grid=True,figsize=(32,15),
                                                  title='Correlation with target')

plt.show()

# %% [markdown]
# # Dividing the Features and Label again

# %%
# Again we Divide data into features and label

X = df.drop(columns = ['W'])
y = df['W']

# %%
X #to see x or feature data
# Out:
#       R    AB   2B  3B   HR   BB    SO   SB   ERA  CG  SHO  SV    E
# 0   724  5575  300  42  139  383   973  104  3.73   2    8  56   88
# 1   696  5467  277  44  156  439  1264   70  4.07   2   12  45   86
# 2   669  5439  303  29  141  533  1157   86  3.67  11   10  38   79
# 3   622  5533  260  27  136  404  1231   68  3.98   7    9  37  101
# 4   689  5605  289  49  151  455  1259   83  4.64   7   12  35   86
# 5   891  5509  308  17  232  570  1151   88  3.80   7   10  34   88
# 6   764  5567  272  19  212  554  1227   63  4.03   3    4  48   93
# 7   713  5485  246  20  217  418  1331   44  4.05   0   10  43   77
# 8   644  5485  278  32  167  436  1310   87  3.74   1   12  60   95
# 9   748  5640  294  33  161  478  1148   71  4.31   3   10  40   97
# 10  751  5511  279  32  172  503  1233  101  4.24   5    9  45  119
# 11  729  5459  278  26  230  486  1392  121  3.57   5   13  39   85
# 12  661  5417  243  21  176  435  1150   52  3.94   2   12  46   93
# ...

# %%
y #to see the target or label data
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 5      93
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %% [markdown]
# # Checking for Outliers

# %%
# we need to check for skewness of data
df.skew().sort_values()
# Out:
# 2B    -0.230650
# SO    -0.156065
# W      0.047089
# ERA    0.053331
# 3B     0.129502
# BB     0.158498
# AB     0.183437
# SB     0.479893
# HR     0.516441
# SHO    0.565790
# SV     0.657524
# CG     0.736845
# E      0.890132
# R      1.200786
# dtype: float64

# %% [markdown]
# ### We see that R and E has the highest skewness and 2B has the lowest skewness in the dataset so we will have to perform treatment to remove skewness so that our model is not biased

# %%
#Lets visualize the data
plt.figure(figsize =(25,40))
graph = 1

for column in df:
    if graph <=17: # as there are 9 columns in data
        plt.subplot(6,3,graph)
        ax=sns.boxplot(data=df[column])
        plt.xlabel(column,fontsize = 15)
        
    graph +=1
plt.show()

# %% [markdown]
# We see that the most outliers is in E column and on the higher side  and there are one-two ouliers approx in columns - R, ERA,SHO and SV , So we need to treat them

# %% [markdown]
# # Considering the outlier removal with Zscore

# %%
df.shape
# Out:
# (30, 14)

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
df_new_z=df[(z<3).all(axis=1)]
df_new_z
# Out:
#       W    R    AB   2B  3B   HR   BB    SO   SB   ERA  CG  SHO  SV    E
# 0    95  724  5575  300  42  139  383   973  104  3.73   2    8  56   88
# 1    83  696  5467  277  44  156  439  1264   70  4.07   2   12  45   86
# 2    81  669  5439  303  29  141  533  1157   86  3.67  11   10  38   79
# 3    76  622  5533  260  27  136  404  1231   68  3.98   7    9  37  101
# 4    74  689  5605  289  49  151  455  1259   83  4.64   7   12  35   86
# 6    87  764  5567  272  19  212  554  1227   63  4.03   3    4  48   93
# 7    81  713  5485  246  20  217  418  1331   44  4.05   0   10  43   77
# 8    80  644  5485  278  32  167  436  1310   87  3.74   1   12  60   95
# 9    78  748  5640  294  33  161  478  1148   71  4.31   3   10  40   97
# 10   88  751  5511  279  32  172  503  1233  101  4.24   5    9  45  119
# 11   86  729  5459  278  26  230  486  1392  121  3.57   5   13  39   85
# 12   85  661  5417  243  21  176  435  1150   52  3.94   2   12  46   93
# ...

# %%
df_new_z.shape
# Out:
# (29, 14)

# %% [markdown]
# ### Percentage of data loss:

# %%
Data_loss = ((30-29)/30)*100

# %%
Data_loss
# Out:
# 3.3333333333333335

# %% [markdown]
# We see that the data loss is 3.33 % approx and this is within the acceptable limit to have the data removed as it improves the skewness of the data

# %%
#Lets see how the data is distributed for every column after the treatment

plt.figure(figsize =(15,20), facecolor = 'white')
plotnumber = 1

for column in df_new_z:
    if plotnumber <=14:
        ax = plt.subplot(5,3,plotnumber)
        sns.distplot(df_new_z[column])
        plt.xlabel(column,fontsize = 12)
        
    plotnumber +=1
plt.tight_layout()

# %% [markdown]
# ### The data looks much better so we will move on with the next step and use the new dataset 'df_new_z'

# %% [markdown]
# # Using SelectKBest Feature Selection Method
#
# Select KBest use f_classif function to find the best features, where f_classif uses Anova Test

# %%
# Again we Divide data into features and label

X = df_new_z.drop(columns = ['W'])
y = df_new_z['W']

# %%
from sklearn.feature_selection import SelectKBest, f_classif

# %%
best_features = SelectKBest(score_func = f_classif, k=13)

fit = best_features.fit(X,y)

df_scores = pd.DataFrame(fit.scores_)

df_columns = pd.DataFrame(X.columns)


#concatenate dataframes

feature_scores = pd.concat([df_columns, df_scores], axis = 1)

feature_scores.columns = ['Feature_name', 'Score']   #name output columns

print(feature_scores.nlargest(13,'Score'))  #Print Best 17 features
# Out:
#    Feature_name     Score
# 7            SB  3.283197
# 11           SV  2.941436
# 12            E  2.492758
# 0             R  2.485509
# 8           ERA  1.732208
# 1            AB  1.622586
# 6            SO  1.519889
# 10          SHO  1.253358
# 5            BB  0.943327
# 4            HR  0.818974
# 3            3B  0.811129
# 2            2B  0.799063
# 9            CG  0.361597

# %% [markdown]
# ### We see that all the features except the CG are the best  as the score they have are greater than 0.5 , but we are only performing this step as a way to analyze the data even further , but we will not remove any columns as the data shows that most of the column is good for prediction

# %% [markdown]
# # Variance Inflation Factor
#
# Checking for Multicollinearity problem to see if one feature is dependent on the other , we need to scale the dat first using MINMAX Scalar

# %%
from sklearn.preprocessing import StandardScaler
scalar= StandardScaler()

# %%
X_scaled = scalar.fit_transform(X)

# %%
X_scaled.shape
# Out:
# (29, 13)

# %%
#Finding variance inflation factor in each scaled column i.e X_scaled.shape[1] (1/(1 -R2))

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif["vif"] = [variance_inflation_factor(X_scaled, i) for i in range(X_scaled.shape[1])]
vif["Features"] = X.columns

#chck Values
vif
# Out:
#          vif Features
# 0   4.428164        R
# 1   2.350073       AB
# 2   3.411045       2B
# 3   3.191726       3B
# 4   4.801655       HR
# 5   2.635823       BB
# 6   2.087109       SO
# 7   1.600146       SB
# 8   4.311503      ERA
# 9   2.267941       CG
# 10  2.928227      SHO
# 11  2.588582       SV
# 12  1.401715        E

# %% [markdown]
# We see that after we have skewed the data , the values are lesser than 5 for all the columns so we will not remove any columns and move to the next step , In the observation we see that R, 2B,3B & ERA are having the highest vif among the rest

# %% [markdown]
# # Principal Component Analysis (PCA)
#
# It is a dimension reduction technique and not a feature selection one.
#
# and we are going to apply on the features only , it is mainly used if there are too many features and no correlation with the target
#
# but its the final analysis we are going to do to chcek for multicollinearity problem

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA()

# %%
pca.fit_transform(X_scaled) #To scale the data with PCA so we can plot the graph to see whats the coverage
# Out:
# array([[-1.97073453e+00, -1.37551442e+00,  2.10118392e+00,
#         -9.84626985e-01, -2.71259667e+00,  5.80196270e-01,
#          5.06870217e-01, -6.22760155e-03,  8.35370560e-01,
#          6.27317187e-01,  3.70835030e-01, -1.10842302e-01,
#         -6.91433539e-02],
#        [-2.66898963e-01,  1.81843261e-01,  3.01083864e-01,
#         -1.79804568e-01, -4.84578018e-01,  7.18452143e-01,
#         -1.16729272e+00, -7.28789151e-01,  2.81733339e-01,
#         -6.40590970e-01, -3.52675737e-01, -2.36984797e-02,
#         -1.04467176e-01],
#        [ 8.56120661e-01, -6.67248798e-01,  5.98150895e-01,
#          3.20403893e+00, -1.24486045e+00, -4.47018503e-01,
#          1.37523570e+00, -1.32740366e+00, -3.49191517e-02,
#          2.45264807e-01, -6.11901156e-01,  1.78729961e-01,
#          1.79811021e-01],
#        [-8.47037504e-01,  1.54943948e+00,  1.38940898e-01,
#          1.01348677e+00,  2.81107292e-01, -1.15891335e+00,
#         -4.91099360e-02, -2.61731194e-01, -5.83356412e-01,
# ...

# %%
# lets plot scree plot to check the best components

plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Principal Components')
plt.ylabel("Variance Covered")
plt.title('PCA')
plt.show()

# %% [markdown]
# ### We see that in order to cover 95% - 100% of the data we need to have only have 9 features and we can remove the rest , We usually in this case will opt to remove , but as this is asmall dataset we will go ahead with it and only remove incase we really need to

# %% [markdown]
# # Creating the Model - Choosing the Best Model

# %% [markdown]
# # Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
scores=[]
for i in range(0,1000):
    X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size = 0.25,random_state = i)
    lr.fit(X_train,y_train)
    pred_train = lr.predict(X_train)
    pred_test = lr.predict(X_test)
    print(f"At random state {i},the training accuracy is :-{r2_score(y_train,pred_train)}")
    print(f"At random state {i},the testing accuracy is :-{r2_score(y_test,pred_test)}")
    print('\n')
    scores.append(r2_score(y_test,pred_test))
# Out:
# At random state 0,the training accuracy is :-0.9820512106365671
# At random state 0,the testing accuracy is :-0.21886774607654813
#
#
# At random state 1,the training accuracy is :-0.9576517667304753
# At random state 1,the testing accuracy is :-0.7219831616255483
#
#
# At random state 2,the training accuracy is :-0.9521117889124847
# At random state 2,the testing accuracy is :--0.14127589681197228
#
#
# At random state 3,the training accuracy is :-0.9725291660798843
# At random state 3,the testing accuracy is :-0.3718332436191445
#
#
# At random state 4,the training accuracy is :-0.9585193130249887
# At random state 4,the testing accuracy is :-0.798506303724113
#
#
# At random state 5,the training accuracy is :-0.9565662815028835
# At random state 5,the testing accuracy is :-0.6078817362215837
#
#
# At random state 6,the training accuracy is :-0.9637794173514648
# At random state 6,the testing accuracy is :-0.6944165204167224
#
#
# ...

# %% [markdown]
# # We have seen that the best random stae for the observations is 286
#
# At random state 286,the training accuracy is :-0.9398627440254177
#
# At random state 286,the testing accuracy is :-0.9213593183858219

# %% [markdown]
# ### Finding the highest using argmax

# %%
np.argmax(scores)
# Out:
# 189

# %%
scores[np.argmax(scores)]
# Out:
# 0.9606799728289226

# %% [markdown]
# We will not sue this state as the training score is lesser than testing , which is not good for the model , so we will go with random state 286 as our best

# %%
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size = 0.25,random_state = 286)

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(X_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.9213593183858219

# %% [markdown]
# # We observed that among all the scores we see the ones which are better for our model is where the difference between the training and testing score is the least which is 286
#
#
# We also observe thatwe need to have a higher training score compared to testing score . so are not going to go with argmax as the ideal random state as its giveng a high test score but it giving a lower train score ,
#
# But  we are choosing random state :-
# At random state 286,the training accuracy is :-0.9398627440254177
# At random state 286,the testing accuracy is :-0.9213593183858219
#
# Reason being this state has the least of the least differnce betwwen the training and testing score and is the highest

# %% [markdown]
# # Cross-Validation of the model

# %%
Train_accuracy=r2_score(y_train,pred_train)
Test_accuracy=r2_score(y_test,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,X_scaled,y,cv=j)
    cv_mean=cv_score.mean()
    print(f"At cross fold{j} the cv score is {cv_mean} and accuracy score for training is {Train_accuracy}and the accuracy for testing is {Test_accuracy}")
    print('\n')
# Out:
# At cross fold2 the cv score is -1.2375458261182444 and accuracy score for training is -0.9751506895863882and the accuracy for testing is 0.9213593183858219
#
#
# At cross fold3 the cv score is 0.28881173741747074 and accuracy score for training is -0.9751506895863882and the accuracy for testing is 0.9213593183858219
#
#
# At cross fold4 the cv score is 0.33834309722902006 and accuracy score for training is -0.9751506895863882and the accuracy for testing is 0.9213593183858219
#
#
# At cross fold5 the cv score is 0.34061603705003496 and accuracy score for training is -0.9751506895863882and the accuracy for testing is 0.9213593183858219
#
#
# At cross fold6 the cv score is 0.31420834408093234 and accuracy score for training is -0.9751506895863882and the accuracy for testing is 0.9213593183858219
#
#
# At cross fold7 the cv score is 0.1600434570366886 and accuracy score for training is -0.9751506895863882and the accuracy for testing is 0.9213593183858219
#
#
# ...

# %% [markdown]
# ### We observe that we are getting really bad Cross val score here we see that among the 10 states , 8 is the only one which is having the closest difference with the testing score , we also see that the training score has increased by 5% approx to 97.5 % and the test score is more less the same @ 92.1%
#
# We need to keep in mind the size of data , as a factor which could make the model feel the data is overfitted as well

# %% [markdown]
# # Plotting the linear Regression graph with actual and predicted values comparison

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(x=y_test, y=pred_test,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual Wins',fontsize=14)
plt.ylabel('Predicted Wins',fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.show()

# %% [markdown]
# ## We see that the model is doing exceptionally well in predicting , here we see the actual and predicted are on the same line which is really good

# %% [markdown]
# # Regularization of the Linear Model

# %%
from sklearn.model_selection import GridSearchCV #to select the pest parameters for hyperparameter tuning
from sklearn.model_selection import cross_val_score #to check the difference from the earlier score without hyper parameter tuning

# %%
from sklearn.linear_model import Lasso

parameters ={'alpha' : [.0001, .001, .01, .1, 1, 10],
            'random_state' : list(range(0,15))}
ls = Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(X_train, y_train)

print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %% [markdown]
# # Final model training for Linear Regression

# %%
ls = Lasso(alpha= 1, random_state= 0)
ls.fit(X_train,y_train)
ls_score_training = ls.score(X_train,y_train)
pred_ls = ls.predict(X_test)
ls_score_training*100
# Out:
# 88.73232683489375

# %% [markdown]
# We are getting a good lasso score of 88.73% which is very high to the cross val score 39% approx for training we got earlier so we can cosider the model is doing moderaltely well but not good enough we need to test more models

# %% [markdown]
# # Checking MSE,RMSE score

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, pred_test))
print('MSE:', metrics.mean_squared_error(y_test, pred_test))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred_test)))
# Out:
# MAE: 2.7521768973240466
# MSE: 9.476202134508469
# RMSE: 3.07834405720161

# %% [markdown]
# We see good values in MAE , MSE and RMSE in the linear model so we will move to other models

# %% [markdown]
# ### Now let us use different model to check which is the best one

# %% [markdown]
# # Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

dt=DecisionTreeRegressor()
dt.fit(X_train,y_train)
dt.score(X_train,y_train)
pred_test =dt.predict(X_test)
dfs = r2_score(y_test,pred_test)
print('R2 Score :',dfs*100)

dfscore = cross_val_score(dt,X_scaled,y,cv=2)
dfc =dfscore.mean()
print('Cross Val Score :',dfc*100)
# Out:
# R2 Score : 58.19502074688796
# Cross Val Score : -53.94287617576764

# %% [markdown]
# ## We observe that for Decision tree regressor :-
# - The model is not at all working well for the data set and we see that the score is very low compared to linear regression model
# - we also see that the cross val score is alos very bad compared to linear , and we cannot choose this over the linear model
# - there is very high  difference between the r2 score  58.19% and cross val score  -53.94%
# - we see that the score is much much  than Linear regression model of 92% approx
# - tryin the next model which is knn

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, pred_test))
print('MSE:', metrics.mean_squared_error(y_test, pred_test))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred_test)))
# Out:
# MAE: 6.125
# MSE: 50.375
# RMSE: 7.097534783289195

# %% [markdown]
# We again see much much lower score in term of mse and mae score compared to Linear Regression model

# %% [markdown]
# # K- Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsRegressor

knn=KNeighborsRegressor()
knn.fit(X_train,y_train)
knn.score(X_train,y_train)
pred_test =knn.predict(X_test)
knns = r2_score(y_test,pred_test)
print('R2 Score :',knns*100)

knnscore = cross_val_score(knn,X_scaled,y,cv=2)
knnc =knnscore.mean()
print('Cross Val Score :',knnc*100)
# Out:
# R2 Score : 47.2780082987552
# Cross Val Score : 15.680722423851428

# %% [markdown]
# # We observe that for K-nearest neighbors :-
# - The model is not at all working well for the data set and we see that the score is very low compared to linear regression model and Decision tree
# - we also see that the cross val score is alos very bad compared to linear , and we cannot choose this over the linear model but its better that Decision tree cv score
# - there is very high  difference between the r2 score  47.27% and cross val score  15.68%
# - we see that the score is much much  than Linear regression model of 92% approx
# - tryin the next model which is Enseble techniques , and we will use Random Forest Regressor

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, pred_test))
print('MSE:', metrics.mean_squared_error(y_test, pred_test))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred_test)))
# Out:
# MAE: 6.699999999999999
# MSE: 63.52999999999999
# RMSE: 7.97057087039567

# %% [markdown]
# We again see much much lower score in term of mse and mae score compared to Linear Regression model

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

rf=RandomForestRegressor()

# %%
scores=[]
for i in range(0,1000):
    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.25,random_state = i)
    rf.fit(X_train,y_train)
    pred_train = rf.predict(X_train)
    pred_test = rf.predict(X_test)
    print(f"At random state {i},the training accuracy is :-{r2_score(y_train,pred_train)}")
    print(f"At random state {i},the testing accuracy is :-{r2_score(y_test,pred_test)}")
    print('\n')
    scores.append(r2_score(y_test,pred_test))
# Out:
# At random state 0,the training accuracy is :-0.9178892442201619
# At random state 0,the testing accuracy is :-0.6013003572410001
#
#
# At random state 1,the training accuracy is :-0.9365085176841631
# At random state 1,the testing accuracy is :-0.7720246205733559
#
#
# At random state 2,the training accuracy is :-0.9261261484098939
# At random state 2,the testing accuracy is :--1.051927121579494
#
#
# At random state 3,the training accuracy is :-0.903134044609277
# At random state 3,the testing accuracy is :-0.5568421504453267
#
#
# At random state 4,the training accuracy is :-0.9180725650038113
# At random state 4,the testing accuracy is :-0.71997762610288
#
#
# At random state 5,the training accuracy is :-0.9249767396095718
# At random state 5,the testing accuracy is :-0.6175678793256434
#
#
# At random state 6,the training accuracy is :-0.9330073582462307
# At random state 6,the testing accuracy is :-0.6172858387799567
#
#
# ...

# %%
np.argmax(scores)
# Out:
# 129

# %%
scores[np.argmax(scores)]
# Out:
# 0.9072900887573965

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.25,random_state = 129)

# %%
rf.fit(X_train,y_train)
rf.score(X_train,y_train)
pred_decision =rf.predict(X_test)

rfs = r2_score(y_test,pred_decision)
print('R2 Score :',rfs*100)

rfscore = cross_val_score(rf,X_scaled,y,cv=4)
rfc =rfscore.mean()
print('Cross Val Score :',rfc*100)
# Out:
# R2 Score : 90.62678994082842
# Cross Val Score : 49.53745718287916

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, pred_test))
print('MSE:', metrics.mean_squared_error(y_test, pred_test))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred_test)))
# Out:
# MAE: 8.14375
# MSE: 101.59475694444444
# RMSE: 10.079422450936583

# %% [markdown]
# We see that the MAE and MSE scores are also worse and this model is not working well with the dataset as well

# %% [markdown]
# # We observe that for Random Forest Regressor :-
# - The model is not  working well for the data set and we see that the score is very low compared to linear regression model , but higher than Decision Tree as well as Knn Regressor
# - we also see that the cross val score is a little better compared to linear, but  we cannot choose this over the linear model but its better that Decision tree cv score @ 49.17%
# - there is very high  difference between the r2 score  90.38% and cross val score  49.17%
# - we see that the score is lesser than Linear regression model of 96% approx
# - tryin the next model which is Ensemble techniques , and we will use Ada boosted Trees

# %% [markdown]
# # ADA Boost Regressor

# %%
scores=[]
for i in range(0,1000):
    X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size = 0.25,random_state = i)
    ada.fit(X_train,y_train)
    pred_train = ada.predict(X_train)
    pred_test = ada.predict(X_test)
    print(f"At random state {i},the training accuracy is :-{r2_score(y_train,pred_train)}")
    print(f"At random state {i},the testing accuracy is :-{r2_score(y_test,pred_test)}")
    print('\n')
    scores.append(r2_score(y_test,pred_test))
# Out:
# At random state 0,the training accuracy is :-0.9928688110420009
# At random state 0,the testing accuracy is :-0.5185490519373455
#
#
# At random state 1,the training accuracy is :-0.9814341604179405
# At random state 1,the testing accuracy is :-0.6872372119168071
#
#
# At random state 2,the training accuracy is :-0.9888723695210319
# At random state 2,the testing accuracy is :--1.0730306567969645
#
#
# At random state 3,the training accuracy is :-0.9934807304725589
# At random state 3,the testing accuracy is :-0.6289263273360279
#
#
# At random state 4,the training accuracy is :-0.9915581499019952
# At random state 4,the testing accuracy is :-0.6624394844134154
#
#
# At random state 5,the training accuracy is :-0.9951933727284995
# At random state 5,the testing accuracy is :-0.5882874889086069
#
#
# At random state 6,the training accuracy is :-0.9825457868352416
# At random state 6,the testing accuracy is :-0.5456763215438202
#
#
# ...

# %%
np.argmax(scores)
# Out:
# 655

# %%
scores[np.argmax(scores)]
# Out:
# 0.9134023724345698

# %%
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size = 0.25,random_state = 655)

# %%
from sklearn.ensemble import AdaBoostRegressor
ada = AdaBoostRegressor()

ada.fit(X_train,y_train)
ada.score(X_train,y_train)
pred_decision =ada.predict(X_test)

adas = r2_score(y_test,pred_decision)
print('R2 Score :',adas*100)

adascore = cross_val_score(ada,X_scaled,y,cv=7)
adac =adascore.mean()
print('Cross Val Score :',adac*100)
# Out:
# R2 Score : 87.2484361597523
# Cross Val Score : -49.77240381907732

# %%
#Checking MAE MSE and RMSE scores
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, pred_decision))
print('MSE:', metrics.mean_squared_error(y_test, pred_decision))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred_decision)))
# Out:
# MAE: 2.529166666666667
# MSE: 10.581805555555555
# RMSE: 3.2529687295692766

# %% [markdown]
# # We observe that for ADA Boost Regressor :-
# - The model is not  working well for the data set and we see that the score is very low compared to linear regression model , but higher than Decision Tree as well as Knn Regressor and lower that Random forest
# - we also see that the cross val score is a much much lower  compared to linear and all the models ,   we cannot choose this over the linear model
# - there is very high  difference between the r2 score  87.24% and cross val score  -49.77%
# - we see that the score is lesser than Linear regression model of 96% approx
# - tryin the next model which is SVR model

# %% [markdown]
# # SVR

# %%
from sklearn.svm import SVR
svr = SVR()

# %%
scores=[]
for i in range(0,1000):
    X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size = 0.25,random_state = i)
    svr.fit(X_train,y_train)
    pred_train = svr.predict(X_train)
    pred_test = svr.predict(X_test)
    print(f"At random state {i},the training accuracy is :-{r2_score(y_train,pred_train)}")
    print(f"At random state {i},the testing accuracy is :-{r2_score(y_test,pred_test)}")
    print('\n')
    scores.append(r2_score(y_test,pred_test))
# Out:
# At random state 0,the training accuracy is :-0.20460193919616254
# At random state 0,the testing accuracy is :--0.033555607438473745
#
#
# At random state 1,the training accuracy is :-0.20048014302065587
# At random state 1,the testing accuracy is :-0.08924532668049223
#
#
# At random state 2,the training accuracy is :-0.25790465633656123
# At random state 2,the testing accuracy is :--3.2053508979608045
#
#
# At random state 3,the training accuracy is :-0.22149938782708511
# At random state 3,the testing accuracy is :-0.045566303662481156
#
#
# At random state 4,the training accuracy is :-0.19747793414745207
# At random state 4,the testing accuracy is :-0.07365461224351144
#
#
# At random state 5,the training accuracy is :-0.22340669747237052
# At random state 5,the testing accuracy is :-0.05468332113683716
#
#
# At random state 6,the training accuracy is :-0.24631831459249598
# At random state 6,the testing accuracy is :-0.06800206326809721
#
#
# ...

# %%
np.argmax(scores)
# Out:
# 989

# %%
scores[np.argmax(scores)]
# Out:
# 0.1944911748562297

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.25,random_state = 989)

# %%
from sklearn.svm import SVR
svr = SVR()

svr.fit(X_train,y_train)
svr.score(X_train,y_train)
pred_decision =svr.predict(X_test)

svrs = r2_score(y_test,pred_decision)
print('R2 Score :',svrs*100)

svrscore = cross_val_score(svr,X,y,cv=8)
svrc =svrscore.mean()
print('Cross Val Score :',svrc*100)
# Out:
# R2 Score : 0.04052248477461884
# Cross Val Score : -78.56388852727892

# %%
#Checking MAE MSE and RMSE scores
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, pred_test))
print('MSE:', metrics.mean_squared_error(y_test, pred_test))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred_test)))
# Out:
# MAE: 3.4525123698387166
# MSE: 20.865392492830868
# RMSE: 4.567865200816555

# %% [markdown]
# We see that SVR is really not a good model for this data set as the values it is giving is inaccurate and highly not usable as we are getting negative -78.56%  on cross val and R2 score as 4% accurate we will not consider this model

# %% [markdown]
# ## So in conclusion we can choose Linear Regression as the BEST MODEL for the dataset

# %% [markdown]
# # Hyper parameter Tuning with SGD Regressor which is similar to Liner Regression and has parameters unlike the Linear model which does not

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import SGDRegressor

#Creating parameters to pass in GridSearchCV

parameters = {'loss' :['squared_error', 'huber', 'epsilon_insensitive', 'squared_epsilon_insensitive'],
             'penalty' :['l1', 'l2', 'elasticnet'],
             'alpha': [0.0001, 0.001, 0.01, 0.1, 1, 10, 100],
             'learning_rate': ['constant', 'optimal', 'invscaling', 'adaptive'],
              'eta0': [1, 10, 100]
             }
lr=SGDRegressor()
clf= GridSearchCV(lr,parameters,cv=8,verbose=2,n_jobs=-1)
clf.fit(X_train,y_train)

print(clf.best_params_)
# Out:
# Fitting 8 folds for each of 1008 candidates, totalling 8064 fits
# {'alpha': 1, 'eta0': 1, 'learning_rate': 'adaptive', 'loss': 'squared_epsilon_insensitive', 'penalty': 'elasticnet'}

# %%
lr=SGDRegressor(alpha=1,eta0=1,learning_rate='adaptive',loss='squared_epsilon_insensitive',penalty='elasticnet')

# %%
scores=[]
for i in range(0,1000):
    X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size = 0.25,random_state = i)
    lr.fit(X_train,y_train)
    pred_train = lr.predict(X_train)
    pred_test = lr.predict(X_test)
    print(f"At random state {i},the training accuracy is :-{r2_score(y_train,pred_train)}")
    print(f"At random state {i},the testing accuracy is :-{r2_score(y_test,pred_test)}")
    print('\n')
    scores.append(r2_score(y_test,pred_test))
# Out:
# At random state 0,the training accuracy is :-0.8858687824581892
# At random state 0,the testing accuracy is :-0.6629262765340656
#
#
# At random state 1,the training accuracy is :-0.8556820470292303
# At random state 1,the testing accuracy is :-0.8848922666998171
#
#
# At random state 2,the training accuracy is :-0.7856243650746901
# At random state 2,the testing accuracy is :--0.3993116176409499
#
#
# At random state 3,the training accuracy is :-0.8753454622395167
# At random state 3,the testing accuracy is :-0.7802644006491309
#
#
# At random state 4,the training accuracy is :-0.7362961516406769
# At random state 4,the testing accuracy is :-0.6498156332537295
#
#
# At random state 5,the training accuracy is :-0.768064845851779
# At random state 5,the testing accuracy is :-0.24097789643401335
#
#
# At random state 6,the training accuracy is :-0.8428973010317484
# At random state 6,the testing accuracy is :-0.6226234945412961
#
#
# ...

# %%
np.argmax(scores)
# Out:
# 292

# %%
scores[np.argmax(scores)]
# Out:
# 0.9502035726284312

# %%
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size = 0.25,random_state = 292)

# %%
lr.fit(X_train,y_train)
lr.score(X_train,y_train)
pred_decision =lr.predict(X_test)

lrs = r2_score(y_test,pred_decision)
print('R2 Score :',lrs*100)

lrscore = cross_val_score(lr,X_scaled,y,cv=2)
lrc =lrscore.mean()
print('Cross Val Score :',lrc*100)
# Out:
# R2 Score : 95.06709775876855
# Cross Val Score : 41.64445021172248

# %%
#Checking MAE MSE and RMSE scores
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, pred_decision))
print('MSE:', metrics.mean_squared_error(y_test, pred_decision))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred_decision)))
# Out:
# MAE: 2.1525820000812743
# MSE: 5.611176299400766
# RMSE: 2.368792160448182

# %% [markdown]
# ### OBSERVATIONS ON FINAL SCORES FROM LINEAR REGRESSION or SGD Regressor
#
# - We see that the accuracy score has dipped down a little bit from Linear Model which has 96% but as we cannot do hyperparameter tuning on the Linear regression Model we will use this but the model we cjose had on 92% so overall we have the best test score in linear model
#
# - We see that the Cross val score is again very very low and shows that the dataset is not able to come over the problem of over fitting due to its size , But after tuning we see that we have an increase of 3% approx
#
# - We also see that we have good MAE and MSE scores compared to the rest of the models and we have chosed the actuall best model for this data set even with all the constraints
#
# - So fnally we choose this model and move it into saved folder to be used - SGD Regressor

# %%
#Plotting distplot to show equillibrium 

sns.distplot(y_test-pred_decision)
plt.show()

# %%
plt.scatter(y_test, pred_decision, alpha = 0.5)
plt.xlabel("y_test")
plt.ylabel("pred_test")
plt.show()

# %%
import pickle
filename = 'baseball_scores.pkl'
pickle.dump(lr,open(filename,'wb'))

# %% [markdown]
# # Conclusion

# %%
loaded_model = pickle.load(open('baseball_scores.pkl','rb'))
result = loaded_model.score(X_test,y_test)
print(result*100)
# Out:
# 95.06709775876855

# %%
conclusion = pd.DataFrame([loaded_model.predict(X_test)[:],pred_decision[:]],index=['Predicted','Orignal'])

# %%
conclusion
# Out:
#                   0          1          2          3          4          5  \
# Predicted  82.02106  95.885673  79.921319  64.919091  80.201987  69.921021
# Orignal    82.02106  95.885673  79.921319  64.919091  80.201987  69.921021
#
#                    6          7
# Predicted  71.570717  88.061416
# Orignal    71.570717  88.061416

# %% [markdown]
# ### We see that the model has predicted the charges on 8 columns againest the actual charges , - the LinearModel which we have chosen as the best one
