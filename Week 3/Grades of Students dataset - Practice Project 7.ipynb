# %% [markdown]
# # Grades of Students dataset - Practice Project 7

# %% [markdown]
# ![image_2022-11-17_054121790.png](attachment:image_2022-11-17_054121790.png)

# %% [markdown]
# ![image_2022-11-17_054156475.png](attachment:image_2022-11-17_054156475.png)

# %% [markdown]
# # Importing the Dataset:

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Grades.csv") #reading the data file
df #diplaying the 1st 5 rows and last 5 rows of the dataset
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# ...

# %%
df.shape #The Total number of data (same as df)
# Out:
# (571, 43)

# %%
df.columns #to see the columns names
# Out:
# Index(['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
#        'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
#        'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
#        'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
#        'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
#        'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
#        'CS-412', 'CGPA'],
#       dtype='object')

# %% [markdown]
# As mentioned in the problem statement the columns PH-121 has the Department name first 2 letters and the first number is the year the Student took that exam , there are total 4 years mentioned here

# %%
df.head() #to see 5 first row of dataset
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
#
# [5 rows x 43 columns]

# %% [markdown]
# # Checking for NULL values if any in the data frame
#
# np.nan, None, NaN and others..

# %%
df.isnull().sum()
# Out:
# Seat No.      0
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %% [markdown]
# We see a significant amount of NULL values in all the courses , mostly in CS-406 and CS 412 as these may have been electives the students did not opt for in their 3rd or 4th year , so there would be many students who wouldnt have attended this.
#
# IN order to treat this we cannot remove these values as they are significat , so we can replace these values with 0 and then then encode the grades from 1 -being the lowest grade upwards

# %%
#CAN ALSO USE

print (df.info()) #to check for null Values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    object
#  1   PH-121     571 non-null    object
#  2   HS-101     571 non-null    object
#  3   CY-105     570 non-null    object
#  4   HS-105/12  570 non-null    object
#  5   MT-111     569 non-null    object
#  6   CS-105     571 non-null    object
#  7   CS-106     569 non-null    object
#  8   EL-102     569 non-null    object
#  9   EE-119     569 non-null    object
#  10  ME-107     569 non-null    object
#  11  CS-107     569 non-null    object
#  12  HS-205/20  566 non-null    object
#  13  MT-222     566 non-null    object
#  14  EE-222     564 non-null    object
#  15  MT-224     564 non-null    object
#  16  CS-210     564 non-null    object
#  17  CS-211     566 non-null    object
#  18  CS-203     566 non-null    object
# ...

# %% [markdown]
# We have rechecked again and found many null values

# %%
df.fillna(value = 0,
          inplace = True) #Replacing the NAN Values with 0 as there is no mark present in it

# %%
df['CS-406'].unique() #as this was one column which was having many NAN values
# Out:
# array(['A-', 'A', 'B-', 'B', 'B+', 0, 'C+', 'D', 'D+', 'C-', 'C', 'A+',
#        'F', 'W', 'WU'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Seat No.     0
# PH-121       0
# HS-101       0
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-105       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# CS-210       0
# CS-211       0
# CS-203       0
# CS-214       0
# EE-217       0
# CS-212       0
# CS-215       0
# MT-331       0
# EF-303       0
# HS-304       0
# CS-301       0
# CS-302       0
# TC-383       0
# MT-442       0
# EL-332       0
# CS-318       0
# CS-306       0
# CS-312       0
# CS-317       0
# CS-403       0
# CS-421       0
# CS-406       0
# CS-414       0
# CS-419       0
# CS-423       0
# CS-412       0
# CGPA         0
# dtype: int64

# %%
df
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# ...

# %% [markdown]
# We have successfully replaced the null values with ) as they have got 0 for not attending that exam and we cant deal with NAN values in the data while building a model

# %% [markdown]
# # Check the datatypes of the columns

# %%
df.dtypes
# Out:
# Seat No.      object
# PH-121        object
# HS-101        object
# CY-105        object
# HS-105/12     object
# MT-111        object
# CS-105        object
# CS-106        object
# EL-102        object
# EE-119        object
# ME-107        object
# CS-107        object
# HS-205/20     object
# MT-222        object
# EE-222        object
# MT-224        object
# CS-210        object
# CS-211        object
# CS-203        object
# CS-214        object
# EE-217        object
# CS-212        object
# CS-215        object
# MT-331        object
# EF-303        object
# HS-304        object
# CS-301        object
# CS-302        object
# TC-383        object
# MT-442        object
# EL-332        object
# CS-318        object
# CS-306        object
# CS-312        object
# CS-317        object
# CS-403        object
# CS-421        object
# CS-406        object
# CS-414        object
# CS-419        object
# CS-423        object
# CS-412        object
# CGPA         float64
# ...

# %% [markdown]
# We can observe that there are in total 42 columns which are Object data i.e :-
#   - most of the scores are mentioned in grades as well as their subject name and year as well
#   - we see the seat no is aso mentioned as the name
# We can also observe that the Target variable (CGPA) is float data and Continuous in nature
#
# Therefore , we can conclude from this part that we need to treat categorical data from the dataset.

# %%
df['Seat No.'].nunique() # we see there are some examples of unique data in the target variable
# Out:
# 571

# %%
#lets check for the categoriacal data as we will need to treat them 

df['PH-121'].unique()
# Out:
# array(['B-', 'A', 'D', 'A-', 'B+', 'B', 'C+', 'C', 'C-', 'D+', 'WU', 'A+',
#        'F'], dtype=object)

# %%
# Checking the unique values in each column

for col in df:
    print(df[col].unique(),'\n')
# Out:
# ['CS-97001' 'CS-97002' 'CS-97003' 'CS-97004' 'CS-97005' 'CS-97006'
#  'CS-97007' 'CS-97008' 'CS-97009' 'CS-97010' 'CS-97011' 'CS-97012'
#  'CS-97013' 'CS-97014' 'CS-97015' 'CS-97016' 'CS-97017' 'CS-97018'
#  'CS-97019' 'CS-97020' 'CS-97021' 'CS-97022' 'CS-97023' 'CS-97024'
#  'CS-97025' 'CS-97026' 'CS-97027' 'CS-97028' 'CS-97029' 'CS-97030'
#  'CS-97031' 'CS-97032' 'CS-97033' 'CS-97034' 'CS-97035' 'CS-97036'
#  'CS-97037' 'CS-97038' 'CS-97039' 'CS-97040' 'CS-97041' 'CS-97042'
#  'CS-97043' 'CS-97044' 'CS-97045' 'CS-97046' 'CS-97047' 'CS-97048'
#  'CS-97049' 'CS-97050' 'CS-97051' 'CS-97052' 'CS-97053' 'CS-97054'
#  'CS-97055' 'CS-97056' 'CS-97057' 'CS-97058' 'CS-97059' 'CS-97060'
#  'CS-97061' 'CS-97062' 'CS-97063' 'CS-97064' 'CS-97065' 'CS-97066'
#  'CS-97067' 'CS-97068' 'CS-97069' 'CS-97070' 'CS-97071' 'CS-97072'
#  'CS-97073' 'CS-97074' 'CS-97075' 'CS-97076' 'CS-97077' 'CS-97078'
#  'CS-97079' 'CS-97080' 'CS-97081' 'CS-97082' 'CS-97083' 'CS-97084'
# ...

# %% [markdown]
# ## We see that most of the columns with marks are having values like 'A-', 'A', 'B-', 'B', 'B+', 0, 'C+', 'D', 'D+', 'C-', 'C', 'A+','F', 'W', 'WU' and they need to be treated with ordinal encoding

# %%
df['HS-101'].unique()
# Out:
# array(['D+', 'D', 'B', 'C+', 'A-', 'B-', 'C-', 'B+', 'C', 'A', 'A+', 'F'],
#       dtype=object)

# %%
df['CGPA'].nunique()
# Out:
# 491

# %% [markdown]
# We see 491 values for target which is CGPA , 571 values for Seat NO. and 15 values approx  for all the marks columns

# %%
# Checking to see if any of the values in Charges is white spaces

df.loc[df['CGPA'] == " "]
# Out:
# Empty DataFrame
# Columns: [Seat No., PH-121, HS-101, CY-105, HS-105/12, MT-111, CS-105, CS-106, EL-102, EE-119, ME-107, CS-107, HS-205/20, MT-222, EE-222, MT-224, CS-210, CS-211, CS-203, CS-214, EE-217, CS-212, CS-215, MT-331, EF-303, HS-304, CS-301, CS-302, TC-383, MT-442, EL-332, CS-318, CS-306, CS-312, CS-317, CS-403, CS-421, CS-406, CS-414, CS-419, CS-423, CS-412, CGPA]
# Index: []
#
# [0 rows x 43 columns]

# %% [markdown]
# We see none so lets move on

# %% [markdown]
# # Making a DATAFRAME From the nominal data to treat

# %%
df_visualization_nominal=df.drop(columns = ['CGPA','Seat No.']) # moving the column with nominal data to an object

# %%
df_visualization_nominal.columns #checking to see the object columns data
# Out:
# Index(['PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111', 'CS-105', 'CS-106',
#        'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20', 'MT-222', 'EE-222',
#        'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214', 'EE-217', 'CS-212',
#        'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301', 'CS-302', 'TC-383',
#        'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312', 'CS-317', 'CS-403',
#        'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423', 'CS-412'],
#       dtype='object')

# %%
df_visualization_nominal.shape
# Out:
# (571, 41)

# %%
df_visualization_nominal.head()
# Out:
#   PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119 ME-107  \
# 0     B-     D+     C-         C     C-     D+      D     C-     B-     C-
# 1      A      D     D+         D     B-      C      D      A     D+      D
# 2      A      B      A        B-     B+      A     B-     B+     A-     A-
# 3      D     C+     D+         D      D     A-     D+     C-      D     C+
# 4     A-     A-     A-        B+      A      A     A-     B+      A     A-
#
#    ... CS-306 CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412
# 0  ...      C     C-     C-     C-     C-     A-      A     C-      B     A-
# 1  ...      D     D+      D      C      D     A-     B-      C      C      B
# 2  ...     A-      B      B      A      C      A      A      A     A-      A
# 3  ...     C-     D+      C     D+     C-     B-      B     C+     C+     C+
# 4  ...     A-     B-     B+     B+     B-     A-      A     A-     A-      A
#
# [5 rows x 41 columns]

# %% [markdown]
# # Visualization of the Nominal Data
#
# For the nominal categorical data we will use Countplot as it gives the frequency of the classes of the columns:

# %%
import seaborn as sns
import matplotlib.pyplot as plt


import warnings
warnings.filterwarnings('ignore')

# %%
#Lets see how the data is distributed for every column as a whole

plt.figure(figsize =(25,30), facecolor = 'white')
plotnumber = 1

for column in df_visualization_nominal:
    if plotnumber <=41: # as there are 17 columns in data
        ax = plt.subplot(14,3,plotnumber)
        sns.countplot(df_visualization_nominal[column])
        plt.xlabel(column,fontsize = 10)
        
    plotnumber +=1
plt.tight_layout()

# %% [markdown]
# ### Lets see the representation individually now with each column as we are not able to see properly in this graph

# %%
df_visualization_nominal.columns
# Out:
# Index(['PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111', 'CS-105', 'CS-106',
#        'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20', 'MT-222', 'EE-222',
#        'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214', 'EE-217', 'CS-212',
#        'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301', 'CS-302', 'TC-383',
#        'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312', 'CS-317', 'CS-403',
#        'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423', 'CS-412'],
#       dtype='object')

# %%
ax = sns.countplot(x='PH-121',data = df_visualization_nominal)
print(df_visualization_nominal['PH-121'].value_counts())
# Out:
# A-    112
# A     111
# B+     61
# B      57
# B-     56
# D      44
# C      33
# C+     31
# D+     22
# A+     22
# C-     19
# WU      2
# F       1
# Name: PH-121, dtype: int64

# %% [markdown]
# From the above observations we can see that the A- and the A grade constitute for the most in the dataset and the least is F
#
# This is a 1st year subject

# %%
ax = sns.countplot(x='HS-101',data = df_visualization_nominal)
print(df_visualization_nominal['HS-101'].value_counts())
# Out:
# A-    82
# B-    78
# C     68
# B     63
# B+    59
# C-    50
# C+    47
# D     45
# A     38
# D+    36
# A+     4
# F      1
# Name: HS-101, dtype: int64

# %% [markdown]
# In this column we see that A- and B- is the highest and F is lowest
#
# This subject is a 1st year subject

# %%
ax = sns.countplot(x='CY-105',data = df_visualization_nominal)
print(df_visualization_nominal['CY-105'].value_counts())
# Out:
# A     177
# A-    120
# B+     50
# B      49
# B-     42
# D      31
# A+     31
# C      19
# C+     17
# C-     16
# D+     14
# WU      3
# 0       1
# F       1
# Name: CY-105, dtype: int64

# %% [markdown]
# A and A- is the highest in this column and ) and F is the lowest
#
# This is a 1st year subject

# %%
ax = sns.countplot(x='CY-105',data = df_visualization_nominal)
print(df_visualization_nominal['CY-105'].value_counts())
# Out:
# A     177
# A-    120
# B+     50
# B      49
# B-     42
# D      31
# A+     31
# C      19
# C+     17
# C-     16
# D+     14
# WU      3
# 0       1
# F       1
# Name: CY-105, dtype: int64

# %% [markdown]
# A- and A and the highest in this column abd 0 and F are the lowest
#
# This is 1st year subject

# %%
ax = sns.countplot(x='HS-105/12',data = df_visualization_nominal)
print(df_visualization_nominal['HS-105/12'].value_counts())
# Out:
# A     96
# A-    75
# B+    70
# B     57
# D     45
# C     41
# B-    40
# C+    39
# C-    36
# D+    34
# A+    34
# WU     2
# 0      1
# F      1
# Name: HS-105/12, dtype: int64

# %% [markdown]
# A and A- are the highest in this columns an 0 and F are the lowest
#
# this is 1st year subject

# %%
ax = sns.countplot(x='MT-111',data = df_visualization_nominal)
print(df_visualization_nominal['MT-111'].value_counts())
# Out:
# A-    105
# A     100
# B-     70
# B+     62
# B      55
# C-     39
# C+     33
# C      30
# D      26
# A+     23
# D+     21
# WU      3
# 0       2
# F       2
# Name: MT-111, dtype: int64

# %% [markdown]
# A- and A are the highest in this column and 0 and F are the lowest
#
# This is a 1st year subject

# %%
ax = sns.countplot(x='CS-105',data = df_visualization_nominal)
print(df_visualization_nominal['CS-105'].value_counts())
# Out:
# A     151
# A-    134
# B+     60
# B      51
# A+     43
# B-     38
# C+     23
# C      22
# C-     22
# D+     15
# D      12
# Name: CS-105, dtype: int64

# %% [markdown]
# A and A- are the highest in thsi columns and D is the lowest
#
# This is 1st year subject

# %%
ax = sns.countplot(x='CS-106',data = df_visualization_nominal)
print(df_visualization_nominal['CS-106'].value_counts())
# Out:
# A-    116
# B+    101
# B      96
# A      56
# B-     54
# C+     41
# D+     29
# C-     27
# D      24
# C      18
# A+      4
# 0       2
# WU      2
# F       1
# Name: CS-106, dtype: int64

# %% [markdown]
# A- and B+ is the highest in thsi column and WU and F are the lowest here
#
# this is 1st year subject

# %%
ax = sns.countplot(x='EL-102',data = df_visualization_nominal) 
print(df_visualization_nominal['EL-102'].value_counts())
# Out:
# A-    105
# A      92
# B+     69
# B      59
# B-     53
# D      38
# C+     35
# C-     32
# C      30
# A+     29
# D+     23
# WU      3
# 0       2
# F       1
# Name: EL-102, dtype: int64

# %% [markdown]
# A- and A are the highest in this column and 0 and F is the lowest
#
# this is 1st year subject

# %%
ax = sns.countplot(x='EE-119',data = df_visualization_nominal)
print(df_visualization_nominal['EE-119'].value_counts())
# Out:
# A-    137
# B+     83
# B      77
# A      68
# B-     48
# C      48
# C+     38
# D+     26
# C-     26
# D      11
# A+      6
# 0       2
# WU      1
# Name: EE-119, dtype: int64

# %% [markdown]
# A- and B+ is the highest in this column and 0 and WU are the lowest
#
# this is 1st year subject

# %%
ax = sns.countplot(x='ME-107',data = df_visualization_nominal)
print(df_visualization_nominal['ME-107'].value_counts())
# Out:
# A-    79
# A     77
# B+    68
# D     56
# B-    56
# B     50
# C     49
# C-    48
# C+    37
# D+    37
# A+     8
# WU     2
# 0      2
# F      2
# Name: ME-107, dtype: int64

# %% [markdown]
# A- and A are the highest in this column
#
# This is a 1st year Subject

# %%
ax = sns.countplot(x='CS-107',data = df_visualization_nominal)
print(df_visualization_nominal['CS-107'].value_counts())
# Out:
# A     105
# A-     81
# B+     57
# B      55
# C-     49
# B-     43
# A+     42
# D      38
# C+     34
# D+     31
# C      30
# 0       2
# WU      2
# I       1
# F       1
# Name: CS-107, dtype: int64

# %% [markdown]
# A ans A- is the highest in this column and I and F are the lowest
#
# this is 1st year subject

# %%
ax = sns.countplot(x='HS-205/20',data = df_visualization_nominal)
print(df_visualization_nominal['HS-205/20'].value_counts())
# Out:
# A-    150
# A     118
# B      97
# B+     89
# B-     36
# C+     33
# C      15
# C-     11
# D+      9
# 0       5
# D       3
# A+      2
# F       2
# WU      1
# Name: HS-205/20, dtype: int64

# %% [markdown]
# A- and A are the highest in thsi columns and F and WU are the lowest
#
# this is 2nd year subject

# %%
ax = sns.countplot(x='MT-222',data = df_visualization_nominal)
print(df_visualization_nominal['MT-222'].value_counts())
# Out:
# A-    86
# A     80
# D     66
# B     61
# B-    52
# D+    46
# C     43
# B+    42
# C+    39
# C-    30
# A+    16
# 0      5
# F      3
# WU     1
# W      1
# Name: MT-222, dtype: int64

# %% [markdown]
# A- and A are the highest in this column and WU and W are the lowest
#
# this is 2nd year subject

# %%
ax = sns.countplot(x='EE-222',data = df_visualization_nominal)
print(df_visualization_nominal['EE-222'].value_counts())
# Out:
# A     122
# A-    121
# B+     65
# B      53
# C      39
# B-     35
# A+     32
# C+     29
# D      25
# D+     21
# C-     16
# 0       7
# F       4
# W       2
# Name: EE-222, dtype: int64

# %% [markdown]
# A and A- are the highest in this column and F and W are the lowest
#
# this is a 2nd year subject

# %%
ax = sns.countplot(x='MT-224',data = df_visualization_nominal)
print(df_visualization_nominal['MT-224'].value_counts())
# Out:
# A-    120
# A      80
# B+     65
# B      57
# B-     49
# C-     43
# C+     39
# D+     37
# D      31
# C      30
# A+     10
# 0       7
# WU      1
# W       1
# F       1
# Name: MT-224, dtype: int64

# %% [markdown]
# A- and A are the highest in this column and W and F are the lowest
#
# this is a 2nd year subject

# %%
ax = sns.countplot(x='CS-210',data = df_visualization_nominal)
print(df_visualization_nominal['CS-210'].value_counts())
# Out:
# A-    133
# A     101
# B+     84
# B      59
# B-     58
# C      30
# C+     27
# C-     24
# D+     21
# D      12
# A+     12
# 0       7
# WU      1
# W       1
# F       1
# Name: CS-210, dtype: int64

# %% [markdown]
# A- and A are the highest in this columns and W and F and WU are the lowest
#
# This is a 2nd year subject

# %%
ax = sns.countplot(x='CS-211',data = df_visualization_nominal)
print(df_visualization_nominal['CS-211'].value_counts())
# Out:
# A-    68
# A     67
# B-    60
# D+    56
# B+    56
# B     56
# C+    55
# C-    50
# C     39
# D     33
# A+    21
# 0      5
# F      3
# WU     1
# W      1
# Name: CS-211, dtype: int64

# %% [markdown]
# A- amd A are the highest in this column and WU and W are the lowest
#
# This is a 2nd year subject

# %%
ax = sns.countplot(x='CS-203',data = df_visualization_nominal)
print(df_visualization_nominal['CS-203'].value_counts())
# Out:
# A-    88
# A     81
# B     66
# C+    62
# B+    59
# B-    53
# D+    39
# C     35
# C-    35
# D     30
# A+    15
# 0      5
# F      2
# I      1
# Name: CS-203, dtype: int64

# %% [markdown]
# A- and A are the highest in this column and I is the lowest
#
# This is 2nd year subject

# %%
ax = sns.countplot(x='CS-214',data = df_visualization_nominal)
print(df_visualization_nominal['CS-214'].value_counts())
# Out:
# C     76
# A-    73
# B     63
# C-    57
# B-    56
# A     56
# D+    47
# C+    46
# B+    45
# D     31
# A+    12
# 0      6
# F      2
# I      1
# Name: CS-214, dtype: int64

# %% [markdown]
# C and A- are the higest in thsi columns and I is the lowest
#
# This is 2nd Year Subject

# %%
ax = sns.countplot(x='EE-217',data = df_visualization_nominal)
print(df_visualization_nominal['EE-217'].value_counts())
# Out:
# A-    137
# A      97
# B+     70
# B      63
# B-     57
# C      36
# C+     29
# A+     22
# C-     20
# D+     19
# D      12
# 0       6
# F       2
# WU      1
# Name: EE-217, dtype: int64

# %% [markdown]
# A- and A are the higest in thsi column and Wu is the lowest
#
# This is  2nd year subject

# %%
ax = sns.countplot(x='CS-212',data = df_visualization_nominal)
print(df_visualization_nominal['CS-212'].value_counts())
# Out:
# A-    101
# B+     86
# B      81
# B-     65
# C      44
# A      43
# D+     36
# C+     35
# C-     35
# D      33
# 0       6
# A+      4
# WU      2
# Name: CS-212, dtype: int64

# %% [markdown]
# A- and B+ are the higest in the column and Wu is the lowest in the column
#
# This is 2nd year subject

# %%
ax = sns.countplot(x='CS-215',data = df_visualization_nominal)
print(df_visualization_nominal['CS-215'].value_counts())
# Out:
# A-    79
# A     68
# B     64
# B-    59
# C+    50
# B+    50
# C     48
# C-    47
# D     42
# D+    38
# A+    17
# 0      6
# WU     1
# W      1
# F      1
# Name: CS-215, dtype: int64

# %% [markdown]
# A- and A are the highest in this column and WU,W and F are the lowest
#
# This is 2nd year subject

# %%
ax = sns.countplot(x='MT-331',data = df_visualization_nominal)
print(df_visualization_nominal['MT-331'].value_counts())
# Out:
# A     118
# A-    103
# B+     64
# B      57
# B-     46
# C-     32
# D+     31
# A+     30
# C      28
# C+     27
# D      22
# 0       9
# F       4
# Name: MT-331, dtype: int64

# %% [markdown]
# A and A- are the highest and F is the lowest
#
# this is 3rd year subject

# %%
ax = sns.countplot(x='EF-303',data = df_visualization_nominal)
print(df_visualization_nominal['EF-303'].value_counts())
# Out:
# B     112
# B-     92
# C      61
# B+     59
# C+     58
# C-     56
# D+     49
# A-     38
# D      19
# A      14
# 0      10
# F       2
# WU      1
# Name: EF-303, dtype: int64

# %% [markdown]
# B and B- are the higest in this and F an WU are the lowest
#
# This is 3rd year subject

# %%
ax = sns.countplot(x='HS-304',data = df_visualization_nominal)
print(df_visualization_nominal['HS-304'].value_counts())
# Out:
# A-    128
# B      72
# B-     70
# B+     66
# C      58
# C+     53
# C-     33
# A      28
# D      20
# D+     19
# 0      10
# F       6
# A+      4
# WU      2
# W       2
# Name: HS-304, dtype: int64

# %% [markdown]
# A- and B are the highest WU and W are the lowest
#
# this is 3rd year subject

# %%
ax = sns.countplot(x='CS-301',data = df_visualization_nominal)
print(df_visualization_nominal['CS-301'].value_counts())
# Out:
# A-    108
# B+     74
# B      71
# A      66
# B-     60
# C      41
# C+     37
# C-     36
# D      29
# D+     29
# 0      10
# A+      9
# F       1
# Name: CS-301, dtype: int64

# %% [markdown]
# A- and B+ are higest F is lowets and 3rd year subject

# %%
ax = sns.countplot(x='CS-302',data = df_visualization_nominal)
print(df_visualization_nominal['CS-302'].value_counts())
# Out:
# A-    113
# B     102
# A      86
# B+     81
# B-     60
# C+     32
# C      28
# D      21
# C-     19
# D+     10
# 0      10
# A+      9
# Name: CS-302, dtype: int64

# %% [markdown]
# A- & B are the highest and A+ is the lowest, this is 3rd year subject

# %%
ax = sns.countplot(x='TC-383',data = df_visualization_nominal)
print(df_visualization_nominal['TC-383'].value_counts())
# Out:
# A     105
# A-     73
# B+     68
# B      59
# C+     44
# D+     44
# C-     42
# C      42
# B-     40
# A+     23
# D      20
# 0      10
# F       1
# Name: TC-383, dtype: int64

# %% [markdown]
# A and A+ are the highest and F is the lowest , this is 3rd year subject

# %%
ax = sns.countplot(x='MT-442',data = df_visualization_nominal)
print(df_visualization_nominal['MT-442'].value_counts())
# Out:
# A-    140
# A     130
# B+     65
# B      47
# A+     39
# B-     30
# C-     28
# C+     24
# C      24
# D      20
# D+     13
# 0      10
# F       1
# Name: MT-442, dtype: int64

# %% [markdown]
# A- and A are the highest and F is he lowest, 3rd year subject

# %%
ax = sns.countplot(x='EL-332',data = df_visualization_nominal)
print(df_visualization_nominal['EL-332'].value_counts())
# Out:
# A-    96
# A     76
# B+    68
# B     67
# B-    62
# C     49
# C+    38
# C-    32
# D+    22
# D     22
# A+    20
# 0      9
# F      9
# WU     1
# Name: EL-332, dtype: int64

# %% [markdown]
# A- and A are the highest and WU is lowest , 3rd year subject

# %%
ax = sns.countplot(x='CS-318',data = df_visualization_nominal)
print(df_visualization_nominal['CS-318'].value_counts())
# Out:
# A-    89
# B-    69
# B     68
# B+    65
# C     53
# C+    49
# A     42
# C-    40
# D     36
# D+    29
# F     10
# 0      9
# A+     6
# WU     5
# W      1
# Name: CS-318, dtype: int64

# %% [markdown]
# A- and B- are the highest and W is lowest , 3rd year subject

# %%
ax = sns.countplot(x='CS-306',data = df_visualization_nominal)
print(df_visualization_nominal['CS-306'].value_counts())
# Out:
# A-    120
# B+     75
# A      74
# B-     64
# B      53
# C-     40
# C      37
# C+     36
# D      31
# D+     18
# A+     10
# 0       9
# F       3
# WU      1
# Name: CS-306, dtype: int64

# %% [markdown]
# A- and B+ are the highest , WU is lowest , 3rd year subject

# %%
ax = sns.countplot(x='CS-312',data = df_visualization_nominal)
print(df_visualization_nominal['CS-312'].value_counts())
# Out:
# A+    93
# A     86
# A-    63
# D+    52
# C     48
# C-    44
# B+    42
# B     37
# C+    37
# B-    36
# D     19
# 0     10
# F      2
# W      1
# WU     1
# Name: CS-312, dtype: int64

# %% [markdown]
# A+ and A are the higest and WU is lowest , 3rd Year subject

# %%
ax = sns.countplot(x='CS-317',data = df_visualization_nominal)
print(df_visualization_nominal['CS-317'].value_counts())
# Out:
# B-    79
# B     75
# C     70
# A-    66
# B+    58
# C+    57
# A     47
# C-    41
# D+    34
# D     16
# 0     12
# A+     9
# F      7
# Name: CS-317, dtype: int64

# %% [markdown]
# B- and B are the highest and F is lowest , 3rd year subject

# %%
ax = sns.countplot(x='CS-403',data = df_visualization_nominal)
print(df_visualization_nominal['CS-403'].value_counts())
# Out:
# A     133
# A-    106
# B+     62
# B-     55
# B      54
# D+     35
# C      33
# C+     32
# C-     30
# A+     15
# 0      12
# D       4
# Name: CS-403, dtype: int64

# %% [markdown]
# A and A- is the highest , D is the lowest , 4th year subject

# %%
ax = sns.countplot(x='CS-421',data = df_visualization_nominal)
print(df_visualization_nominal['CS-421'].value_counts())
# Out:
# B     86
# B-    74
# C     68
# C+    61
# C-    60
# B+    60
# A-    47
# D+    36
# A     25
# D     21
# F     17
# 0     12
# A+     2
# W      2
# Name: CS-421, dtype: int64

# %% [markdown]
# B and B- is the highest , A+ and W is lowest , 4th Yr subject

# %%
ax = sns.countplot(x='CS-406',data = df_visualization_nominal)
print(df_visualization_nominal['CS-406'].value_counts())
# Out:
# A-    177
# 0      85
# A      79
# B+     64
# B      58
# B-     22
# C+     22
# C      19
# D+     14
# C-      8
# A+      8
# F       6
# D       5
# W       3
# WU      1
# Name: CS-406, dtype: int64

# %% [markdown]
# A- and 0 are highest WU is lowest , 4th year subject

# %%
ax = sns.countplot(x='CS-414',data = df_visualization_nominal)
print(df_visualization_nominal['CS-414'].value_counts())
# Out:
# A     176
# A-    156
# B+     62
# B      54
# B-     21
# A+     21
# C+     21
# C      20
# 0      13
# C-     12
# F       7
# D+      3
# D       3
# W       2
# Name: CS-414, dtype: int64

# %% [markdown]
# A ans A- is the highest , W is lowest , 4th yr subject

# %%
ax = sns.countplot(x='CS-419',data = df_visualization_nominal)
print(df_visualization_nominal['CS-419'].value_counts())
# Out:
# A-    120
# B      89
# B+     85
# B-     78
# A      56
# C+     46
# C      40
# C-     20
# 0      13
# D+     13
# D       7
# A+      2
# F       2
# Name: CS-419, dtype: int64

# %% [markdown]
# A- and B are the highest , A+ and F are lowest , 4th year Subject

# %%
ax = sns.countplot(x='CS-423',data = df_visualization_nominal)
print(df_visualization_nominal['CS-423'].value_counts())
# Out:
# A-    122
# A      78
# B+     75
# B      65
# B-     56
# C      45
# C+     39
# C-     29
# D+     25
# D      15
# 0      14
# F       5
# A+      3
# Name: CS-423, dtype: int64

# %% [markdown]
# A- and A are the highest , A+is lowest , 4th yr subject

# %%
ax = sns.countplot(x='CS-412',data = df_visualization_nominal)
print(df_visualization_nominal['CS-412'].value_counts())
# Out:
# A-    157
# B+     80
# 0      79
# A      77
# B      65
# B-     37
# C+     24
# C      19
# D+      8
# C-      7
# F       6
# D       5
# A+      4
# W       3
# Name: CS-412, dtype: int64

# %% [markdown]
# A- and B+ are the highest , W is lowest , 4th yr Subject

# %% [markdown]
# # Checking the distribution of the continuous value of the float and int columns.

# %%
df_visualization_continuous=df[['CGPA','Seat No.']].copy()

# %%
df_visualization_continuous
# Out:
#       CGPA  Seat No.
# 0    2.205  CS-97001
# 1    2.008  CS-97002
# 2    3.608  CS-97003
# 3    1.906  CS-97004
# 4    3.448  CS-97005
# ..     ...       ...
# 566  3.798  CS-97567
# 567  3.772  CS-97568
# 568  3.470  CS-97569
# 569  2.193  CS-97570
# 570  1.753  CS-97571
#
# [571 rows x 2 columns]

# %% [markdown]
# ## Lets graph the continuos and nominal data with distplot

# %%
sns.distplot(df['CGPA'],kde=True)
# Out:
# <AxesSubplot:xlabel='CGPA', ylabel='Density'>

# %% [markdown]
# We can see that the Target variable is the only numerical column is somewhat evenly distributed.
#
# We cannot make any changes with this column so we will move ahead

# %% [markdown]
# We can see that the most of the charges lies in range 0 to 5000 and the second highest chunk lies between 5000 to 10000

# %% [markdown]
# ## Since the dataset has a lot of string values. We will use encoding techniques to convert the string data to numerical data

# %% [markdown]
# ### Encoding the dataframe with Label Encoder as the values we have marks and we have used the marks from the official grading for CGPA grade

# %% [markdown]
# ![mldb1.JPG](attachment:mldb1.JPG)

# %% [markdown]
# ![image_2022-11-18_053615124.png](attachment:image_2022-11-18_053615124.png)

# %% [markdown]
# Credits to :-
#     https://catalog.csun.edu/policies/grading-symbols/ img 2
#
#
#         https://blog.collegevine.com/how-to-convert-your-gpa-to-a-4-0-scale/ img 1

# %%
df_visualization_nominal.replace({"A+": 4.0, "A": 4.0, "A-": 3.7, "B+": 3.3, "B": 3.0,"B-":2.7,"C+": 2.3,"C":2.0 , "C-": 1.7, "D+": 1.3,"D" : 1.0,"F": 0.0, "W" : 0.0, "WU": 0.0, "I": 0.0, 0 : 0.0 }, inplace = True)

# %%
df_visualization_nominal.dtypes # Checking the dat type to make sure we have converted all the columns
# Out:
# PH-121       float64
# HS-101       float64
# CY-105       float64
# HS-105/12    float64
# MT-111       float64
# CS-105       float64
# CS-106       float64
# EL-102       float64
# EE-119       float64
# ME-107       float64
# CS-107       float64
# HS-205/20    float64
# MT-222       float64
# EE-222       float64
# MT-224       float64
# CS-210       float64
# CS-211       float64
# CS-203       float64
# CS-214       float64
# EE-217       float64
# CS-212       float64
# CS-215       float64
# MT-331       float64
# EF-303       float64
# HS-304       float64
# CS-301       float64
# CS-302       float64
# TC-383       float64
# MT-442       float64
# EL-332       float64
# CS-318       float64
# CS-306       float64
# CS-312       float64
# CS-317       float64
# CS-403       float64
# CS-421       float64
# CS-406       float64
# CS-414       float64
# CS-419       float64
# CS-423       float64
# CS-412       float64
# dtype: object

# %% [markdown]
# ## So we have officially converted our grades to marks so we can use with our model and we used Label Encoder

# %%
df1 = pd .concat([df_visualization_continuous,df_visualization_nominal],axis=1)
df1
# Out:
#       CGPA  Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  \
# 0    2.205  CS-97001     2.7     1.3     1.7        2.0     1.7     1.3
# 1    2.008  CS-97002     4.0     1.0     1.3        1.0     2.7     2.0
# 2    3.608  CS-97003     4.0     3.0     4.0        2.7     3.3     4.0
# 3    1.906  CS-97004     1.0     2.3     1.3        1.0     1.0     3.7
# 4    3.448  CS-97005     3.7     3.7     3.7        3.3     4.0     4.0
# ..     ...       ...     ...     ...     ...        ...     ...     ...
# 566  3.798  CS-97567     3.0     4.0     4.0        3.7     4.0     4.0
# 567  3.772  CS-97568     4.0     4.0     4.0        4.0     4.0     4.0
# 568  3.470  CS-97569     3.0     4.0     3.7        3.3     4.0     4.0
# 569  2.193  CS-97570     4.0     3.3     1.0        4.0     1.0     1.3
# 570  1.753  CS-97571     2.0     1.0     1.0        2.0     2.0     1.3
#
#      CS-106  EL-102  ...  CS-306  CS-312  CS-317  CS-403  CS-421  CS-406  \
# ...

# %% [markdown]
# ## We have created a new dataframe object called df1 as we have both the Arget and the grades and have finished the datacleaning process

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
enc=OrdinalEncoder()

# %%
df1['Seat No.']=enc.fit_transform(df['Seat No.'].values.reshape(-1,1))

# %%
df1.tail() # we see the values have been converted to numerical data which the machne understands
# Out:
#       CGPA  Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  \
# 566  3.798     566.0     3.0     4.0     4.0        3.7     4.0     4.0
# 567  3.772     567.0     4.0     4.0     4.0        4.0     4.0     4.0
# 568  3.470     568.0     3.0     4.0     3.7        3.3     4.0     4.0
# 569  2.193     569.0     4.0     3.3     1.0        4.0     1.0     1.3
# 570  1.753     570.0     2.0     1.0     1.0        2.0     2.0     1.3
#
#      CS-106  EL-102  ...  CS-306  CS-312  CS-317  CS-403  CS-421  CS-406  \
# 566     3.7     3.7  ...     3.3     3.7     3.7     4.0     4.0     4.0
# 567     4.0     3.7  ...     3.7     3.3     3.3     4.0     4.0     3.7
# 568     4.0     4.0  ...     3.3     3.7     3.0     4.0     3.3     4.0
# 569     2.7     1.7  ...     3.3     1.0     3.0     3.0     1.7     1.0
# 570     3.0     2.3  ...     1.3     2.3     2.0     2.7     1.0     0.0
#
#      CS-414  CS-419  CS-423  CS-412
# 566     3.3     3.3     3.0     4.0
# ...

# %%
df['Seat No.'].nunique()
# Out:
# 571

# %% [markdown]
# # OBSERVATIONS:-
#
# WE have converted the grades columns 41 of them according to the marks in the Standard Scale based on CGPA evaluation
#
# We have converted the SEat no column with all the roll no to index having values 1 to 571

# %% [markdown]
# # EDA

# %% [markdown]
# ### Describing the Dataset

# %%
df1.describe()
# Out:
#              CGPA    Seat No.      PH-121      HS-101      CY-105   HS-105/12  \
# count  571.000000  571.000000  571.000000  571.000000  571.000000  571.000000
# mean     2.954888  285.000000    2.998424    2.603503    3.248511    2.853940
# std      0.620552  164.977776    0.978083    0.911248    0.939995    1.025704
# min      0.800000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      2.538000  142.500000    2.300000    2.000000    2.700000    2.000000
# 50%      3.029000  285.000000    3.300000    2.700000    3.700000    3.000000
# 75%      3.451000  427.500000    3.700000    3.300000    4.000000    3.700000
# max      3.985000  570.000000    4.000000    4.000000    4.000000    4.000000
#
#            MT-111      CS-105      CS-106      EL-102  ...      CS-306  \
# count  571.000000  571.000000  571.000000  571.000000  ...  571.000000
# mean     2.967776    3.312084    2.932049    2.947636  ...    2.869527
# ...

# %% [markdown]
# We notice all values are accounted for
#
# the mean and std of each coloumn are fairly good
#
# we have no outlier in most cases and no data reduntantcy, so moving to visualizing the data with heatmap to check for relationship of features

# %% [markdown]
# # Visualization of the Data

# %%
#Lets see how the data is distributed for every column

import matplotlib.pyplot as plt
plt.figure(figsize=(22,10))
sns.heatmap(df1.describe(),annot=True,linewidths=0.1,linecolor="black",fmt='0.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# We see that there is not any extreme valuesas the data is ordinal for grades and the Seat no has high valuesas it is also ordinal as it shows the index of the student

# %% [markdown]
# # Correlation of the columns with the target Columns

# %%
df1.corr()['CGPA'].sort_values()
# Out:
# Seat No.     0.054342
# CS-406       0.292669
# CS-412       0.458067
# CS-414       0.507611
# HS-205/20    0.525166
# HS-101       0.561814
# CS-312       0.588254
# CS-106       0.599289
# MT-331       0.615512
# EF-303       0.622772
# CS-105       0.629329
# CS-423       0.633162
# EE-222       0.635864
# CS-318       0.659137
# CS-107       0.659853
# MT-442       0.662856
# CS-403       0.666412
# HS-105/12    0.667734
# EL-102       0.672426
# HS-304       0.674736
# PH-121       0.677015
# CY-105       0.683432
# EE-119       0.687948
# ME-107       0.697916
# CS-203       0.700100
# TC-383       0.702550
# CS-211       0.702826
# MT-222       0.711437
# EE-217       0.725965
# CS-212       0.726065
# CS-419       0.743447
# MT-224       0.757133
# CS-421       0.771341
# MT-111       0.771876
# CS-302       0.780169
# CS-301       0.782274
# CS-214       0.785983
# CS-306       0.790566
# CS-215       0.793554
# EL-332       0.812020
# CS-210       0.820402
# ...

# %% [markdown]
# ### We see that most of the data points are highly correlated but we will not act on it as it is all categorical data converted to ordinal data, and the numerical columns in the set is having less than 0.5 which is Seat no.

# %% [markdown]
# ## Heatmap of Correlation of the columns within the Columns or Features and Target

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#size of canvas
plt.figure(figsize=(32,15))
sns.heatmap(df1.corr(),annot=True, linewidths=0.5,linecolor='black', fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Again we notice that most of the columns have high reltionship with each other which means that they are all constituting to the CGPA or target but as we need the model to calculate the total CGPA after 4 years of education we will keep all the columns for now . and make changes if we are not getting the best fit

# %%
df1.drop('CGPA', axis=1).corrwith(df1.CGPA).plot(kind='bar', grid=True,figsize=(32,15),
                                                  title='Correlation with target')

plt.show()

# %% [markdown]
# ### As we have seen before from the heat map we see similar reading from the bar plot as well where most of the grades have high positive correlation with target variable

# %% [markdown]
# ### Lets visualize the relationship between our independent vaiables and the categories

# %%
#Divide data into features and label

X = df1.drop(columns = ['CGPA'])
y = df['CGPA']

# %%
X #to see x or feature data
# Out:
#      Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0         0.0     2.7     1.3     1.7        2.0     1.7     1.3     1.0
# 1         1.0     4.0     1.0     1.3        1.0     2.7     2.0     1.0
# 2         2.0     4.0     3.0     4.0        2.7     3.3     4.0     2.7
# 3         3.0     1.0     2.3     1.3        1.0     1.0     3.7     1.3
# 4         4.0     3.7     3.7     3.7        3.3     4.0     4.0     3.7
# ..        ...     ...     ...     ...        ...     ...     ...     ...
# 566     566.0     3.0     4.0     4.0        3.7     4.0     4.0     3.7
# 567     567.0     4.0     4.0     4.0        4.0     4.0     4.0     4.0
# 568     568.0     3.0     4.0     3.7        3.3     4.0     4.0     4.0
# 569     569.0     4.0     3.3     1.0        4.0     1.0     1.3     2.7
# 570     570.0     2.0     1.0     1.0        2.0     2.0     1.3     3.0
#
#      EL-102  EE-119  ...  CS-306  CS-312  CS-317  CS-403  CS-421  CS-406  \
# ...

# %%
y #to see the target or label data
# Out:
# 0      2.205
# 1      2.008
# 2      3.608
# 3      1.906
# 4      3.448
#        ...
# 566    3.798
# 567    3.772
# 568    3.470
# 569    2.193
# 570    1.753
# Name: CGPA, Length: 571, dtype: float64

# %%
#Lets see how the data is distributed for every column as a whole

#Visualizing Relationship

plt.figure(figsize =(25,200), facecolor = 'yellow')
plotnumber = 1

for column in X:
    if plotnumber <=43:
        ax = plt.subplot(22,4,plotnumber)
        plt.scatter(X[column],y)
        plt.xlabel(column,fontsize = 20)
        plt.ylabel('CGPA',fontsize = 10)
    plotnumber +=1

# %% [markdown]
# From the graph we see that higher the grade higher the CGPA which means the data is showing proper relationship  btw target and features

# %%
plt.subplots(figsize=(20,10))
ax=sns.swarmplot(x='Seat No.',y='CGPA',data=df1)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()

# %% [markdown]
# We see that the Seat No. and CGPA have no correaltion at all and it shows a random pattern , Difficult to predict

# %% [markdown]
# # OUTliers Check

# %%
# we need to check for skewness of data
df1.skew()
# Out:
# CGPA        -0.497203
# Seat No.     0.000000
# PH-121      -0.851098
# HS-101      -0.208545
# CY-105      -1.370674
# HS-105/12   -0.566828
# MT-111      -0.830437
# CS-105      -1.240521
# CS-106      -0.973018
# EL-102      -0.816930
# EE-119      -0.826785
# ME-107      -0.371878
# CS-107      -0.643656
# HS-205/20   -1.681455
# MT-222      -0.403255
# EE-222      -1.162048
# MT-224      -0.719657
# CS-210      -1.201459
# CS-211      -0.356482
# CS-203      -0.576310
# CS-214      -0.229501
# EE-217      -1.175959
# CS-212      -0.690034
# CS-215      -0.410022
# MT-331      -0.994047
# EF-303      -0.567443
# HS-304      -0.892465
# CS-301      -0.773047
# CS-302      -1.218164
# TC-383      -0.634430
# MT-442      -1.371063
# EL-332      -0.880896
# CS-318      -0.668588
# CS-306      -0.862962
# CS-312      -0.603549
# CS-317      -0.591698
# CS-403      -1.024586
# CS-421      -0.611088
# CS-406      -1.137928
# CS-414      -2.110248
# CS-419      -1.215163
# ...

# %% [markdown]
# # Since all are categorical in nature we will not treat skewness and Seat no has no skewness even if it is numerical  it is also ordinal in nature

# %%
#Lets visualize the data
plt.figure(figsize =(25,200))
graph = 1

for column in df1:
    if graph <=43: # as there are 9 columns in data
        plt.subplot(22,4,graph)
        ax=sns.boxplot(data=df1[column])
        plt.xlabel(column,fontsize = 15)
        
    graph +=1
plt.show()

# %% [markdown]
# The data is very normally distributed and we have fewer outliers and most of the grades features are categorical in nature so we will not remove them , this is only for visualization

# %% [markdown]
# # Using SelectKBest Feature Selection Method
#
# Select KBest use f_classif function to find the best features, where f_classif uses Anova Test

# %%
#Divide data into features and label

X = df1.drop(columns = ['CGPA'])
y = df['CGPA']

# %%
from sklearn.feature_selection import SelectKBest, f_classif

# %%
best_features = SelectKBest(score_func = f_classif, k=17)

fit = best_features.fit(X,y)

df_scores = pd.DataFrame(fit.scores_)

df_columns = pd.DataFrame(X.columns)


#concatenate dataframes

feature_scores = pd.concat([df_columns, df_scores], axis = 1)

feature_scores.columns = ['Feature_name', 'Score']   #name output columns

print(feature_scores.nlargest(17,'Score'))  #Print Best 17 features
# Out:
#    Feature_name     Score
# 16       CS-210  6.774290
# 27       CS-302  4.535316
# 3        CY-105  3.886110
# 26       CS-301  3.842976
# 30       EL-332  3.635121
# 32       CS-306  3.457188
# 21       CS-212  3.426195
# 1        PH-121  3.354604
# 19       CS-214  3.317784
# 22       CS-215  3.271510
# 34       CS-317  3.145095
# 17       CS-211  2.944919
# 29       MT-442  2.824907
# 36       CS-421  2.737444
# 23       MT-331  2.639604
# 9        EE-119  2.610277
# 25       HS-304  2.562214

# %% [markdown]
# ### We see the best top 17 features , but as we are calculating th CGPA from 4 years of study and marks we will move forward and not omit any columns

# %% [markdown]
# # Variance Inflation Factor
#
# Checking for Multicollinearity problem to see if one feature is dependent on the other , we need to scale the dat first using MINMAX Scalar

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()

# %%
X_scaled = mms.fit_transform(X)

# %%
X_scaled.shape
# Out:
# (571, 42)

# %%
#Finding variance inflation factor in each scaled column i.e X_scaled.shape[1] (1/(1 -R2))

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif["vif"] = [variance_inflation_factor(X_scaled, i) for i in range(X_scaled.shape[1])]
vif["Features"] = X.columns

#chck Values
vif
# Out:
#           vif   Features
# 0   11.988238   Seat No.
# 1   39.489038     PH-121
# 2   16.902348     HS-101
# 3   40.298575     CY-105
# 4   24.095206  HS-105/12
# 5   32.621465     MT-111
# 6   26.099391     CS-105
# 7   30.152220     CS-106
# 8   24.295003     EL-102
# 9   32.599871     EE-119
# 10  20.218603     ME-107
# 11  24.008807     CS-107
# 12  36.266874  HS-205/20
# 13  18.424610     MT-222
# 14  32.041464     EE-222
# 15  32.109778     MT-224
# 16  59.402452     CS-210
# 17  24.844865     CS-211
# 18  28.809182     CS-203
# 19  26.630070     CS-214
# 20  44.206008     EE-217
# 21  36.906600     CS-212
# 22  29.312937     CS-215
# 23  24.020986     MT-331
# 24  27.854764     EF-303
# 25  32.217175     HS-304
# 26  40.761018     CS-301
# 27  48.334913     CS-302
# 28  33.130227     TC-383
# 29  29.634936     MT-442
# 30  37.355115     EL-332
# 31  21.998539     CS-318
# 32  44.970305     CS-306
# 33  34.442761     CS-312
# 34  37.948630     CS-317
# 35  37.671798     CS-403
# ...

# %% [markdown]
# ### All the vif values are having huge values which means that each feature is highlt correlated with each other and we are able to use any portion of the data to predict th e CGPA score , but as we want to calculate the score on a whole we will keep this for now

# %% [markdown]
# # Principal Component Analysis (PCA)
#
# It is a dimension reduction technique and not a feature selection one.
#
# and we are going to apply on the features only , it is mainly used if there are too many features and no correlation with the target
#
# but its the final analysis we are going to do to chcek for multicollinearity problem

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA()

# %%
pca.fit_transform(X_scaled) #To scale the data with PCA so we can plot the graph to see whats the coverage
# Out:
# array([[ 1.23906445,  0.68331338, -0.73506619, ..., -0.09263837,
#         -0.11197931, -0.00950437],
#        [ 1.52810448,  0.66076726, -0.25029725, ..., -0.04705491,
#          0.03000366, -0.01238035],
#        [-1.13934005,  0.52566843, -0.13960728, ..., -0.09368986,
#          0.02515729,  0.09609008],
#        ...,
#        [-0.87835446, -0.36055669,  0.43308636, ..., -0.04165564,
#          0.07595184,  0.09856124],
#        [ 1.10043016, -0.33367512,  0.22621281, ...,  0.04744939,
#         -0.03625497, -0.12569343],
#        [ 1.75096734, -0.59379886,  0.27429665, ...,  0.15227949,
#         -0.05368901, -0.04746452]])

# %%
# lets plot scree plot to check the best components

plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Principal Components')
plt.ylabel("Variance Covered")
plt.title('PCA')
plt.show()

# %% [markdown]
# ### We see that in order to cover 100% of the data we need to have atleast 40-41 features so we will move to model building now and choose the best model

# %% [markdown]
# # Creating the Model - Choosing the Best Model

# %% [markdown]
# # Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
scores=[]
for i in range(0,100):
    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.25,random_state = i)
    lr.fit(X_train,y_train)
    pred_train = lr.predict(X_train)
    pred_test = lr.predict(X_test)
    print(f"At random state {i},the training accuracy is :-{r2_score(y_train,pred_train)}")
    print(f"At random state {i},the testing accuracy is :-{r2_score(y_test,pred_test)}")
    print('\n')
    scores.append(r2_score(y_test,pred_test))
# Out:
# At random state 0,the training accuracy is :-0.9663376011732898
# At random state 0,the testing accuracy is :-0.9290843796708265
#
#
# At random state 1,the training accuracy is :-0.9575733304010543
# At random state 1,the testing accuracy is :-0.9603077693227959
#
#
# At random state 2,the training accuracy is :-0.9710530261814128
# At random state 2,the testing accuracy is :-0.9056418451735443
#
#
# At random state 3,the training accuracy is :-0.9776180617031591
# At random state 3,the testing accuracy is :-0.897355656090536
#
#
# At random state 4,the training accuracy is :-0.9559422067005207
# At random state 4,the testing accuracy is :-0.9680980818962766
#
#
# At random state 5,the training accuracy is :-0.9586807481807651
# At random state 5,the testing accuracy is :-0.957183889342237
#
#
# At random state 6,the training accuracy is :-0.9585962186337966
# At random state 6,the testing accuracy is :-0.9591743257822842
#
#
# ...

# %%
np.argmax(scores)
# Out:
# 23

# %%
scores[np.argmax(scores)]
# Out:
# 0.9770125027142957

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.25,random_state = 322)

# %% [markdown]
# We observed that among all the scores we see the ones which are better for our model is where the difference between the training and testing score is the least which is 1 , 4, 8, etc
#
#
# We also observe thatwe need to have a higher training score compared to testing score . so the ones which have that are 0,2,5,7,etc
#
# But  we are choosing random state 5 where traing accuracy is 0.9586807481807651 and testing is -0.957183889342237 accuracy.
#
# Reason being this state has the least of the least differnce betwwen the training and testing score

# %% [markdown]
# # Cross-Validation of the model

# %%
Train_accuracy=r2_score(y_train,pred_train)
Test_accuracy=r2_score(y_test,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,X,y,cv=j)
    cv_mean=cv_score.mean()
    print(f"At cross fold{j} the cv score is {cv_mean} and accuracy score for training is {Train_accuracy}and the accuracy for testing is {Test_accuracy}")
    print('\n')
# Out:
# At cross fold2 the cv score is 0.8153208293737118 and accuracy score for training is -0.9556892201500231and the accuracy for testing is -0.8749780473880444
#
#
# At cross fold3 the cv score is 0.903574499687144 and accuracy score for training is -0.9556892201500231and the accuracy for testing is -0.8749780473880444
#
#
# At cross fold4 the cv score is 0.9057202326007884 and accuracy score for training is -0.9556892201500231and the accuracy for testing is -0.8749780473880444
#
#
# At cross fold5 the cv score is 0.93501283128012 and accuracy score for training is -0.9556892201500231and the accuracy for testing is -0.8749780473880444
#
#
# At cross fold6 the cv score is 0.938774021593748 and accuracy score for training is -0.9556892201500231and the accuracy for testing is -0.8749780473880444
#
#
# At cross fold7 the cv score is 0.9403049320127667 and accuracy score for training is -0.9556892201500231and the accuracy for testing is -0.8749780473880444
#
#
# ...

# %% [markdown]
# We obsserve that the values for cross val score is  is 94 % and for testing its 87% and we have accuracy score 87% and r2 score which is again 72% ,
#
# So we can conclude that the model is not working properly with this data as the Cross val score is having a big differnce btw the testing and cross val score
#
# Now that we have assumed that we see that state 8 is the best among 10 cross val score

# %% [markdown]
# # Plotting the linear Regression graph with actual and predicted values comparison

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(x=y_test, y=pred_test,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual Charges',fontsize=14)
plt.ylabel('Predicted Charges',fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.savefig('lr1.png')
plt.show()

# %% [markdown]
# ## We see that the model may not be on the line but it is able to predict the data properly after the 2.5 mark as it is increasing with increase in value so the model is doing fairly well

# %% [markdown]
# # Regularization

# %%
from sklearn.model_selection import GridSearchCV #to select the pest parameters for hyperparameter tuning
from sklearn.model_selection import cross_val_score #to check the difference from the earlier score without hyper parameter tuning

# %%
from sklearn.linear_model import Lasso

parameters ={'alpha' : [.0001, .001, .01, .1, 1, 10],
            'random_state' : list(range(0,10))}
ls = Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(X_train, y_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.001, 'random_state': 0}

# %% [markdown]
# # Final model training for Linear Regression

# %%
ls = Lasso(alpha= 0.001, random_state= 0)
ls.fit(X_train,y_train)
ls_score_training = ls.score(X_train,y_train)
pred_ls = ls.predict(X_test)
ls_score_training*100
# Out:
# 95.91900721211792

# %% [markdown]
# We are getting a good lasso score of 95.91% which is very similar to the cross val score 94.8% approx for training we got earlier so we can cosider the model is doing moderaltely well but not good eough we need to test more models

# %% [markdown]
# # Checking MSE,RMSE score

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, pred_test))
print('MSE:', metrics.mean_squared_error(y_test, pred_test))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred_test)))
# Out:
# MAE: 0.7108486859465171
# MSE: 0.7680587663536846
# RMSE: 0.8763896201768279

# %% [markdown]
# We see good values in MAE , MSE and RMSE

# %% [markdown]
# ### Now let us use different model to check which is the best one

# %% [markdown]
# # Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

dt=DecisionTreeRegressor()
dt.fit(X_train,y_train)
dt.score(X_train,y_train)
pred_decision =dt.predict(X_test)

dfs = r2_score(y_test,pred_decision)
print('R2 Score :',dfs*100)

dfscore = cross_val_score(dt,X,y,cv=8)
dfc =dfscore.mean()
print('Cross Val Score :',dfc*100)
# Out:
# R2 Score : 82.29002575749205
# Cross Val Score : 79.34980950132943

# %% [markdown]
# We observe that for Decision tree regressor
# - there is very less difference between the r2 score  82.29% and cross val score  79.34%
# - we see that the score is lesser than Linear regression model of 95% approx

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

rf=RandomForestRegressor()

rf.fit(X_train,y_train)
rf.score(X_train,y_train)
pred_decision =rf.predict(X_test)

rfs = r2_score(y_test,pred_decision)
print('R2 Score :',rfs*100)

rfscore = cross_val_score(rf,X,y,cv=8)
rfc =rfscore.mean()
print('Cross Val Score :',rfc*100)
# Out:
# R2 Score : 94.05429972465382
# Cross Val Score : 94.13538293509815

# %% [markdown]
# We observe that the Random forest Regressor has actually given us a lesser accuracy score but as  better cross val score to compare with almost identical which is very good
# - we see that the r2 score is 94% which is much higher that linear and decision tree model 95% and 82%
# - we see there is very very less difference between the r2 score and cross val score so the model is well fit
# - no overfitting and underfitting as well
# - the model works better for this kind of data

# %% [markdown]
# # XGboost

# %%
import xgboost as xgb
xgb = xgb.XGBRegressor()

xgb.fit(X_train,y_train)
xgb.score(X_train,y_train)
pred_decision =xgb.predict(X_test)

xgbs = r2_score(y_test,pred_decision)
print('R2 Score :',xgbs*100)

xgbscore = cross_val_score(xgb,X,y,cv=8)
xgbc =xgbscore.mean()
print('Cross Val Score :',xgbc*100)
# Out:
# R2 Score : 93.12820338984086
# Cross Val Score : 92.2183428377362

# %% [markdown]
# We observe that the Xgboost Regressor has actually given us a accuracy score of 93% approx
# - we see that the r2 score is 93% which is much higher that linear and decision tree model 95% and 82% but lower than random forest which is 93%
# - we see there is more difference between the r2 score and cross val score compared to Random forest 0.5% almost
# - very less  overfitting and underfitting as well but not as better than Random forest
# - the model is the 2nd best in working best for this kind of data

# %% [markdown]
# # SVR

# %%
from sklearn.svm import SVR
svr = SVR()

svr.fit(X_train,y_train)
svr.score(X_train,y_train)
pred_decision =svr.predict(X_test)

svrs = r2_score(y_test,pred_decision)
print('R2 Score :',svrs*100)

svrscore = cross_val_score(svr,X,y,cv=5)
svrc =svrscore.mean()
print('Cross Val Score :',svrc*100)
# Out:
# R2 Score : 19.255983031600323
# Cross Val Score : 20.655338315197014

# %% [markdown]
# We see that SVR is really not a good model for this data set as the values it is giving is inaccurate and highly not usable as we are getting negative 19% and 20% on cross val and R2 score we will not consider this model

# %% [markdown]
# ## So in conclusion we can choose Random Forest  Regressoras the BEST MODEL for the dataset

# %% [markdown]
# # Hyper parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

#Creating parameters to pass in GridSearchCV

parameters = {'criterion':['mse','mae','rmse'],
             'max_features':['auto','sqrt','log2'],
             'max_features': [2, 3, 4 ,5,7],
             'min_samples_leaf': [3, 4, 5, 6, 7],
             'n_estimators' : [100,200,300,400,500]
             }
rf=RandomForestRegressor()
clf= GridSearchCV(rf,parameters,cv=8,verbose=2)
clf.fit(X_train,y_train)

print(clf.best_params_)
# Out:
# Fitting 8 folds for each of 200 candidates, totalling 1600 fits
# [CV] END criterion=mse, max_features=2, min_samples_leaf=3, n_estimators=100; total time=   0.1s
# [CV] END criterion=mse, max_features=2, min_samples_leaf=3, n_estimators=100; total time=   0.1s
# [CV] END criterion=mse, max_features=2, min_samples_leaf=3, n_estimators=100; total time=   0.1s
# [CV] END criterion=mse, max_features=2, min_samples_leaf=3, n_estimators=100; total time=   0.1s
# [CV] END criterion=mse, max_features=2, min_samples_leaf=3, n_estimators=100; total time=   0.1s
# [CV] END criterion=mse, max_features=2, min_samples_leaf=3, n_estimators=100; total time=   0.1s
# [CV] END criterion=mse, max_features=2, min_samples_leaf=3, n_estimators=100; total time=   0.1s
# [CV] END criterion=mse, max_features=2, min_samples_leaf=3, n_estimators=100; total time=   0.1s
# [CV] END criterion=mse, max_features=2, min_samples_leaf=3, n_estimators=200; total time=   0.2s
# ...

# %%
rf=RandomForestRegressor(criterion='mse',max_features=5,min_samples_leaf=3,n_estimators=400)

rf.fit(X_train,y_train)
rf.score(X_train,y_train)
pred_decision =rf.predict(X_test)

rfs = r2_score(y_test,pred_decision)
print('R2 Score :',rfs*100)

rfscore = cross_val_score(rf,X,y,cv=5)
rfc =rfscore.mean()
print('Cross Val Score :',rfc*100)
# Out:
# R2 Score : 94.36309913505545
# Cross Val Score : 94.52260753636172

# %% [markdown]
# ### We see that we have maintained  the score @ 94.34% approx to 94.36% now which is a good sign and this model is the best for this project

# %%
#Checking MAE MSE and RMSE scores
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, pred_test))
print('MSE:', metrics.mean_squared_error(y_test, pred_test))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred_test)))
# Out:
# MAE: 0.7108486859465171
# MSE: 0.7680587663536846
# RMSE: 0.8763896201768279

# %%
#Plotting distplot to show equillibrium 

sns.distplot(y_test-pred_test)
plt.show()

# %%
plt.scatter(y_test, pred_test, alpha = 0.5)
plt.xlabel("y_test")
plt.ylabel("pred_test")
plt.show()

# %%
import pickle
filename = 'Scores.pkl'
pickle.dump(rf,open(filename,'wb'))

# %% [markdown]
# # Conclusion

# %%
loaded_model = pickle.load(open('Scores.pkl','rb'))
result = loaded_model.score(X_test,y_test)
print(result*100)
# Out:
# 94.36309913505545

# %%
conclusion = pd.DataFrame([loaded_model.predict(X_test)[:],pred_decision[:]],index=['Predicted','Orignal'])

# %%
conclusion
# Out:
#                 0         1         2         3         4         5    \
# Predicted  3.080427  3.731377  3.462935  3.422151  3.713743  2.659712
# Orignal    3.080427  3.731377  3.462935  3.422151  3.713743  2.659712
#
#                 6        7         8         9    ...       133       134  \
# Predicted  2.268663  3.32353  2.414253  3.182932  ...  2.902959  2.988705
# Orignal    2.268663  3.32353  2.414253  3.182932  ...  2.902959  2.988705
#
#                 135       136       137       138       139       140  \
# Predicted  3.878252  3.197617  2.903792  3.516341  2.424635  3.452399
# Orignal    3.878252  3.197617  2.903792  3.516341  2.424635  3.452399
#
#                 141       142
# Predicted  2.689133  3.017034
# Orignal    2.689133  3.017034
#
# [2 rows x 143 columns]

# %% [markdown]
# ### We see that the model has predicted the charges on 143 columns againest the actual charges , so the Random Forest is the best one
